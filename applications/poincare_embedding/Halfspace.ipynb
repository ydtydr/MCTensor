# %% [markdown]
# ## Pytorch Poincare Halfspace embedding for the WordNet Mammals dataset

# %%
import timeit
import torch
from tqdm import tqdm
import numpy as np
import logging
from hype.sn import Embedding 
from hype import train
from hype.graph import load_edge_list, eval_reconstruction
from hype.rsgd import RiemannianSGD
from hype.Halfspace import HalfspaceManifold
import sys, os, random
import json
import torch.multiprocessing as mp
from hype.graph_dataset import BatchedDataset
os.environ["NUMEXPR_MAX_THREADS"] = '8'

def seed_everything(seed=1234):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

d16 = torch.float16; d32 = torch.float32; d64 = torch.float64
cpu = torch.device("cpu"); gpu = torch.device(type='cuda', index=0)
device = cpu
opt_dtype = d64

if opt_dtype == d16:
    dtype = "d16"
    torch.set_default_tensor_type('torch.HalfTensor')
elif opt_dtype == d32:
    dtype = "d32"
    torch.set_default_tensor_type('torch.FloatTensor')
else:
    dtype = "d64"
    torch.set_default_tensor_type('torch.DoubleTensor')
    
torch.manual_seed(42)
np.random.seed(42)

# %% [markdown]
# ### Hyperparameters for PyTorch Poincare Halfspace model:

# %%
## parameters; these are global in the notebook!
opt_maxnorm = 500000; opt_debug = False;
opt_dim = 2; opt_com_n = 1;
opt_negs = 50;  opt_eval_each = 20;
opt_sparse = True; opt_ndproc = 1;  opt_burnin = 20;
opt_dampening = 0.75; opt_neg_multiplier = 1.0; 
opt_burnin_multiplier = 0.01; 
###########################################################
opt_epochs = 1000; opt_batchsize = 32; 
opt_lr = 1.7;  opt_dscale = 0.3
# opt_manifold = "Poincare"
opt_manifold = "Halfspace"
opt_task = 'mammals'
#######################################
FILE_NAME = "_".join([opt_task, 'lr', str(opt_lr), 'batch', str(opt_batchsize),
                      str(opt_epochs), "torch", dtype, str(opt_dscale)])

# %%
MANIFOLDS = {
    'Halfspace': HalfspaceManifold,
}

class RES():
    def __init__(self, loss, eval_res, weight):
        self.loss = torch.tensor(loss, dtype=torch.float64, 
                                 device=cpu)
        self.eval_res = torch.tensor(eval_res, dtype=torch.float64, 
                                     device=cpu)
        self.weight = weight

# %% [markdown]
# ### Initializing logging and data loading

# %%
log_level = logging.DEBUG if opt_debug else logging.INFO
log = logging.getLogger('MCF')
logging.basicConfig(level=log_level, format='%(message)s', stream=sys.stdout)
log.info('Using edge list dataloader')
idx, objects, weights = load_edge_list("wordnet/mammal_closure.csv", False) 
#idx, objects, weights = load_edge_list("/home/jl3789/Hyperbolic_Library/applications/poincare_embedding/wordnet/mammal_closure.csv", False)
# Out:
# Using edge list dataloader

# %% [markdown]
# ### Initializing model

# %%
def init_model(manifold, idx, objects, weights, sparse=True):
    conf = []
    model_name = '%s_dim%d%com_n'
    mname = model_name % (opt_manifold, opt_dim, opt_com_n)
    data = BatchedDataset(idx, objects, weights, opt_negs, opt_batchsize,
        opt_ndproc, opt_burnin > 0, opt_dampening)
    model = Embedding(len(data.objects), opt_dim, manifold, sparse=sparse, com_n=opt_com_n)
    data.objects = objects
    return model, data, mname, conf

def adj_matrix(data):
  adj = {}
  for inputs, _ in data:
    for row in inputs:
        x = row[0].item()
        y = row[1].item()
        if x in adj:
            adj[x].add(y)
        else:
            adj[x] = {y}
  return adj

# %% [markdown]
# ### Training

# %%
def data_loader_lr(data, epoch, progress = False):
  data.burnin = False 
  lr = opt_lr
  if epoch < opt_burnin:
    data.burnin = True
    lr = opt_lr * train._lr_multiplier
  loader_iter = tqdm(data) if progress else data
  return loader_iter, lr

# %%
def train(device, model, data, optimizer, progress=False):
    epoch_loss = torch.Tensor(len(data))
    LOSS = np.zeros(opt_epochs)

    for epoch in range(opt_epochs):
        largest_weight_emb = round(
            torch.abs(model.lt.weight.data).max().item(), 6)
        print(largest_weight_emb, "is the largest absolute weight in the embedding")

        epoch_loss.fill_(0)
        t_start = timeit.default_timer()
        # handling burnin, get loader_iter and learning rate
        loader_iter, lr = data_loader_lr(data, epoch, progress=progress)

        for i_batch, (inputs, targets) in enumerate(loader_iter):
            elapsed = timeit.default_timer() - t_start
            inputs = inputs.to(device)
            targets = targets.to(device)
            optimizer.zero_grad()
            preds = model(inputs) * opt_dscale
            loss = model.loss(preds, targets, size_average=True)
            loss.backward()
            optimizer.step(lr=lr)
            epoch_loss[i_batch] = loss.cpu().item()
            with torch.no_grad():
                loss = model.loss(preds.to(d64), targets, size_average=True)
                epoch_loss[i_batch] = loss.cpu().item()

        LOSS[epoch] = torch.mean(epoch_loss).to(d64).item()
        # since only one thread is used:
        log.info('json_stats: {' f'"epoch": {epoch}, '
                 f'"elapsed": {elapsed}, ' f'"loss": {LOSS[epoch]}, ' '}')
    return LOSS

# %% [markdown]
# # Training embedding

# %%
# setup model
seed_everything(1)
manifold = MANIFOLDS[opt_manifold](
    debug=opt_debug, max_norm=opt_maxnorm, com_n=opt_com_n)
model, data, model_name, conf = init_model(
    manifold, idx, objects, weights, sparse=opt_sparse)
data.neg_multiplier = opt_neg_multiplier
train._lr_multiplier = opt_burnin_multiplier
model = model.to(device)
print('the total dimension', model.lt.weight.data.size(-1), 'com_n', opt_com_n)
print(">>>>>> # Tensor# | dtype is:", model.lt.weight.dtype,
      "| device is:", model.lt.weight.device)
# setup optimizer
optimizer = RiemannianSGD(model.optim_params(manifold), lr=opt_lr)
# get adjacency matrix
adj = adj_matrix(data)
# begin training
start_time = timeit.default_timer()
loss = train(device, model, data, optimizer, progress=False)
train_time = timeit.default_timer() - start_time
print("Total training time is:", train_time)
# Out:
# >>>>>> The size of embedding: Embedding(1180, 2, sparse=True)
# the total dimension 2 com_n 1
# >>>>>> # Tensor# | dtype is: torch.float64 | device is: cpu
# 1.0001 is the largest absolute weight in the embedding
# json_stats: {"epoch": 0, "elapsed": 0.2786331550005343, "loss": 3.9317073897809878, }
# 1.003987 is the largest absolute weight in the embedding
# json_stats: {"epoch": 1, "elapsed": 0.26102172900027654, "loss": 3.931372632110913, }
# 1.007866 is the largest absolute weight in the embedding
# json_stats: {"epoch": 2, "elapsed": 0.3030020739997781, "loss": 3.9310328654829845, }
# 1.011775 is the largest absolute weight in the embedding
# json_stats: {"epoch": 3, "elapsed": 0.2371376169994619, "loss": 3.9306918132824, }
# 1.015683 is the largest absolute weight in the embedding
# json_stats: {"epoch": 4, "elapsed": 0.2785311260004164, "loss": 3.9303460968795503, }
# 1.019605 is the largest absolute weight in the embedding
# json_stats: {"epoch": 5, "elapsed": 0.23592588200062892, "loss": 3.9300069110758247, }
# 1.023515 is the largest absolute weight in the embedding
# json_stats: {"epoch": 6, "elapsed": 0.2650909900003171, "loss": 3.9296647513232275, }
# 1.027392 is the largest absolute weight in the embedding
# json_stats: {"epoch": 7, "elapsed": 0.25129651299994293, "loss": 3.9293185163967133, }
# 1.031328 is the largest absolute weight in the embedding
# json_stats: {"epoch": 8, "elapsed": 0.28403367299961246, "loss": 3.9289838567818447, }
# 1.035262 is the largest absolute weight in the embedding
# json_stats: {"epoch": 9, "elapsed": 0.23712176800017915, "loss": 3.9286300942350354, }
# 1.039195 is the largest absolute weight in the embedding
# json_stats: {"epoch": 10, "elapsed": 0.25743804299963813, "loss": 3.9282803912902935, }
# 1.043172 is the largest absolute weight in the embedding
# json_stats: {"epoch": 11, "elapsed": 0.28767503299968666, "loss": 3.9279392626558502, }
# 1.047147 is the largest absolute weight in the embedding
# json_stats: {"epoch": 12, "elapsed": 0.2592651940003634, "loss": 3.9275949954816043, }
# 1.051126 is the largest absolute weight in the embedding
# json_stats: {"epoch": 13, "elapsed": 0.2565737150007408, "loss": 3.9272495638678886, }
# 1.054846 is the largest absolute weight in the embedding
# json_stats: {"epoch": 14, "elapsed": 0.2700825720003195, "loss": 3.926900629033506, }
# 1.058837 is the largest absolute weight in the embedding
# json_stats: {"epoch": 15, "elapsed": 0.25571049799964385, "loss": 3.9265559668678067, }
# 1.062747 is the largest absolute weight in the embedding
# json_stats: {"epoch": 16, "elapsed": 0.23907359300028475, "loss": 3.926211636154522, }
# 1.066759 is the largest absolute weight in the embedding
# json_stats: {"epoch": 17, "elapsed": 0.2643009359999269, "loss": 3.9258670065805306, }
# 1.070816 is the largest absolute weight in the embedding
# json_stats: {"epoch": 18, "elapsed": 0.30775900299977366, "loss": 3.925526727422132, }
# 1.074865 is the largest absolute weight in the embedding
# json_stats: {"epoch": 19, "elapsed": 0.2665658790001544, "loss": 3.925163836469477, }
# 1.079009 is the largest absolute weight in the embedding
# json_stats: {"epoch": 20, "elapsed": 0.31095277599979454, "loss": 3.926081570136451, }
# 1.148113 is the largest absolute weight in the embedding
# json_stats: {"epoch": 21, "elapsed": 0.301162791999559, "loss": 3.9089139034766003, }
# 1.296392 is the largest absolute weight in the embedding
# json_stats: {"epoch": 22, "elapsed": 0.2973992139995971, "loss": 3.8909170053682915, }
# 1.387316 is the largest absolute weight in the embedding
# json_stats: {"epoch": 23, "elapsed": 0.2986414569995759, "loss": 3.8718107849696226, }
# 1.551487 is the largest absolute weight in the embedding
# json_stats: {"epoch": 24, "elapsed": 0.2637586820001161, "loss": 3.8528560162512426, }
# 1.705617 is the largest absolute weight in the embedding
# json_stats: {"epoch": 25, "elapsed": 0.3481534760003342, "loss": 3.8339474396016224, }
# 1.855953 is the largest absolute weight in the embedding
# json_stats: {"epoch": 26, "elapsed": 0.2690907699998206, "loss": 3.8149406165222577, }
# 2.039358 is the largest absolute weight in the embedding
# json_stats: {"epoch": 27, "elapsed": 0.2966731910000817, "loss": 3.7963818366341977, }
# 2.236694 is the largest absolute weight in the embedding
# json_stats: {"epoch": 28, "elapsed": 0.2722593010003038, "loss": 3.7780616134340823, }
# 2.449073 is the largest absolute weight in the embedding
# json_stats: {"epoch": 29, "elapsed": 0.3156590030002917, "loss": 3.7592256261122348, }
# 2.706183 is the largest absolute weight in the embedding
# json_stats: {"epoch": 30, "elapsed": 0.2686863299995821, "loss": 3.740726624480921, }
# 2.928954 is the largest absolute weight in the embedding
# json_stats: {"epoch": 31, "elapsed": 0.32274875700022676, "loss": 3.722882535728432, }
# 3.251258 is the largest absolute weight in the embedding
# json_stats: {"epoch": 32, "elapsed": 0.27453545600019424, "loss": 3.7045679867440255, }
# 3.567083 is the largest absolute weight in the embedding
# json_stats: {"epoch": 33, "elapsed": 0.3688301450001745, "loss": 3.68613631930716, }
# 3.840916 is the largest absolute weight in the embedding
# json_stats: {"epoch": 34, "elapsed": 0.30350888000066334, "loss": 3.6680456478680497, }
# 4.157578 is the largest absolute weight in the embedding
# json_stats: {"epoch": 35, "elapsed": 0.2846784209996258, "loss": 3.6498971587657913, }
# 4.484625 is the largest absolute weight in the embedding
# json_stats: {"epoch": 36, "elapsed": 0.28162079400044604, "loss": 3.6318678752899025, }
# 4.813274 is the largest absolute weight in the embedding
# json_stats: {"epoch": 37, "elapsed": 0.29809538800054725, "loss": 3.6141187445584504, }
# 5.165314 is the largest absolute weight in the embedding
# json_stats: {"epoch": 38, "elapsed": 0.32028345500020805, "loss": 3.5968382779068993, }
# 5.522369 is the largest absolute weight in the embedding
# json_stats: {"epoch": 39, "elapsed": 0.37463334099993517, "loss": 3.5786083205692454, }
# 5.846736 is the largest absolute weight in the embedding
# json_stats: {"epoch": 40, "elapsed": 0.25001464700017095, "loss": 3.5616830315206243, }
# 6.127807 is the largest absolute weight in the embedding
# json_stats: {"epoch": 41, "elapsed": 0.27319841099961195, "loss": 3.5436786926240087, }
# 6.373842 is the largest absolute weight in the embedding
# json_stats: {"epoch": 42, "elapsed": 0.30693237600007706, "loss": 3.526538912364215, }
# 6.59928 is the largest absolute weight in the embedding
# json_stats: {"epoch": 43, "elapsed": 0.2873161940005957, "loss": 3.510122180604214, }
# 6.773336 is the largest absolute weight in the embedding
# json_stats: {"epoch": 44, "elapsed": 0.2781412269996508, "loss": 3.491816879415409, }
# 6.864798 is the largest absolute weight in the embedding
# json_stats: {"epoch": 45, "elapsed": 0.271712660999583, "loss": 3.474373814276622, }
# 6.998995 is the largest absolute weight in the embedding
# json_stats: {"epoch": 46, "elapsed": 0.32001971499994397, "loss": 3.4570833878794374, }
# 7.600261 is the largest absolute weight in the embedding
# json_stats: {"epoch": 47, "elapsed": 0.240238608999789, "loss": 3.440060257450543, }
# 8.276803 is the largest absolute weight in the embedding
# json_stats: {"epoch": 48, "elapsed": 0.33589209999991, "loss": 3.4245540666696854, }
# 8.866234 is the largest absolute weight in the embedding
# json_stats: {"epoch": 49, "elapsed": 0.3118988429996534, "loss": 3.4067327885562606, }
# 9.379051 is the largest absolute weight in the embedding
# json_stats: {"epoch": 50, "elapsed": 0.26498211000034644, "loss": 3.3903993588037964, }
# 9.965421 is the largest absolute weight in the embedding
# json_stats: {"epoch": 51, "elapsed": 0.2518968809999933, "loss": 3.3725719707966237, }
# 10.433993 is the largest absolute weight in the embedding
# json_stats: {"epoch": 52, "elapsed": 0.3798870850005187, "loss": 3.35738086841982, }
# 10.885535 is the largest absolute weight in the embedding
# json_stats: {"epoch": 53, "elapsed": 0.30988600099954056, "loss": 3.3393173227925113, }
# 11.311094 is the largest absolute weight in the embedding
# json_stats: {"epoch": 54, "elapsed": 0.23827933500069776, "loss": 3.322128362135644, }
# 11.690489 is the largest absolute weight in the embedding
# json_stats: {"epoch": 55, "elapsed": 0.2666781110001466, "loss": 3.3057371984378707, }
# 11.999217 is the largest absolute weight in the embedding
# json_stats: {"epoch": 56, "elapsed": 0.399563758000113, "loss": 3.2903730417469648, }
# 12.229947 is the largest absolute weight in the embedding
# json_stats: {"epoch": 57, "elapsed": 0.24831867000011698, "loss": 3.270968891153391, }
# 12.523236 is the largest absolute weight in the embedding
# json_stats: {"epoch": 58, "elapsed": 0.28246852699976444, "loss": 3.2558479926894335, }
# 12.707213 is the largest absolute weight in the embedding
# json_stats: {"epoch": 59, "elapsed": 0.3280276329996923, "loss": 3.2392743446198886, }
# 12.917159 is the largest absolute weight in the embedding
# json_stats: {"epoch": 60, "elapsed": 0.2783136669995656, "loss": 3.2217183293817646, }
# 13.047972 is the largest absolute weight in the embedding
# json_stats: {"epoch": 61, "elapsed": 0.25822285499998543, "loss": 3.207773825862758, }
# 13.189196 is the largest absolute weight in the embedding
# json_stats: {"epoch": 62, "elapsed": 0.2836939170001642, "loss": 3.1894587365457365, }
# 13.274151 is the largest absolute weight in the embedding
# json_stats: {"epoch": 63, "elapsed": 0.29916031699940504, "loss": 3.1741996457373745, }
# 13.442437 is the largest absolute weight in the embedding
# json_stats: {"epoch": 64, "elapsed": 0.2534443969998392, "loss": 3.16000927282015, }
# 13.471836 is the largest absolute weight in the embedding
# json_stats: {"epoch": 65, "elapsed": 0.33592255399980786, "loss": 3.140312212258849, }
# 13.535606 is the largest absolute weight in the embedding
# json_stats: {"epoch": 66, "elapsed": 0.28394509900044795, "loss": 3.128177127736565, }
# 13.603953 is the largest absolute weight in the embedding
# json_stats: {"epoch": 67, "elapsed": 0.6301759190000666, "loss": 3.1116645388375694, }
# 13.655303 is the largest absolute weight in the embedding
# json_stats: {"epoch": 68, "elapsed": 0.6535669369995958, "loss": 3.0980088647480333, }
# 13.69215 is the largest absolute weight in the embedding
# json_stats: {"epoch": 69, "elapsed": 0.4057417340000029, "loss": 3.0812566718385925, }
# 13.737716 is the largest absolute weight in the embedding
# json_stats: {"epoch": 70, "elapsed": 0.32645060300001205, "loss": 3.0657678796465855, }
# 13.766188 is the largest absolute weight in the embedding
# json_stats: {"epoch": 71, "elapsed": 0.2839270670001497, "loss": 3.050695178877923, }
# 13.831958 is the largest absolute weight in the embedding
# json_stats: {"epoch": 72, "elapsed": 0.30687256999954116, "loss": 3.04099584524954, }
# 14.699701 is the largest absolute weight in the embedding
# json_stats: {"epoch": 73, "elapsed": 0.3413068709996878, "loss": 3.025995860037583, }
# 15.502203 is the largest absolute weight in the embedding
# json_stats: {"epoch": 74, "elapsed": 0.26679874699948414, "loss": 3.012431310604433, }
# 16.247075 is the largest absolute weight in the embedding
# json_stats: {"epoch": 75, "elapsed": 0.32107878499937215, "loss": 2.9962584686878517, }
# 16.950325 is the largest absolute weight in the embedding
# json_stats: {"epoch": 76, "elapsed": 0.28840015300011146, "loss": 2.9821746981624746, }
# 17.563816 is the largest absolute weight in the embedding
# json_stats: {"epoch": 77, "elapsed": 0.3187620449998576, "loss": 2.972163148547081, }
# 18.155968 is the largest absolute weight in the embedding
# json_stats: {"epoch": 78, "elapsed": 0.30390667299980123, "loss": 2.960112561299999, }
# 18.666649 is the largest absolute weight in the embedding
# json_stats: {"epoch": 79, "elapsed": 0.2824637049998273, "loss": 2.9414888457549857, }
# 19.141371 is the largest absolute weight in the embedding
# json_stats: {"epoch": 80, "elapsed": 0.32360628500009625, "loss": 2.9298042878283406, }
# 19.588758 is the largest absolute weight in the embedding
# json_stats: {"epoch": 81, "elapsed": 0.28602515700004005, "loss": 2.92138193470483, }
# 19.957022 is the largest absolute weight in the embedding
# json_stats: {"epoch": 82, "elapsed": 0.2785014230003071, "loss": 2.906377900479057, }
# 20.310757 is the largest absolute weight in the embedding
# json_stats: {"epoch": 83, "elapsed": 0.26599422199979017, "loss": 2.890995009064064, }
# 20.60257 is the largest absolute weight in the embedding
# json_stats: {"epoch": 84, "elapsed": 0.3369004259993744, "loss": 2.8835522904956172, }
# 20.900041 is the largest absolute weight in the embedding
# json_stats: {"epoch": 85, "elapsed": 0.2826899390001927, "loss": 2.868667717210805, }
# 21.133765 is the largest absolute weight in the embedding
# json_stats: {"epoch": 86, "elapsed": 0.2969557870001154, "loss": 2.8565632796440674, }
# 21.366599 is the largest absolute weight in the embedding
# json_stats: {"epoch": 87, "elapsed": 0.33590036500027054, "loss": 2.8438002749441678, }
# 21.557379 is the largest absolute weight in the embedding
# json_stats: {"epoch": 88, "elapsed": 0.2546210290001909, "loss": 2.8349868254004638, }
# 21.720044 is the largest absolute weight in the embedding
# json_stats: {"epoch": 89, "elapsed": 0.2702813360001528, "loss": 2.8246627645404616, }
# 21.860611 is the largest absolute weight in the embedding
# json_stats: {"epoch": 90, "elapsed": 0.3438579169996956, "loss": 2.8101988094606054, }
# 21.99599 is the largest absolute weight in the embedding
# json_stats: {"epoch": 91, "elapsed": 0.3344408229995679, "loss": 2.8024870695369333, }
# 22.109704 is the largest absolute weight in the embedding
# json_stats: {"epoch": 92, "elapsed": 0.5162995109994881, "loss": 2.7908545585894236, }
# 22.213326 is the largest absolute weight in the embedding
# json_stats: {"epoch": 93, "elapsed": 0.37154954400011775, "loss": 2.7783864657567947, }
# 22.312945 is the largest absolute weight in the embedding
# json_stats: {"epoch": 94, "elapsed": 0.3007254700005433, "loss": 2.7654766889190303, }
# 22.385758 is the largest absolute weight in the embedding
# json_stats: {"epoch": 95, "elapsed": 0.34122347199991054, "loss": 2.758090386129364, }
# 22.457273 is the largest absolute weight in the embedding
# json_stats: {"epoch": 96, "elapsed": 0.33780081100030657, "loss": 2.7472212499601327, }
# 22.519086 is the largest absolute weight in the embedding
# json_stats: {"epoch": 97, "elapsed": 0.29126595399975486, "loss": 2.7407219906812252, }
# 22.578055 is the largest absolute weight in the embedding
# json_stats: {"epoch": 98, "elapsed": 0.3888958450006612, "loss": 2.7310661173851445, }
# 22.637061 is the largest absolute weight in the embedding
# json_stats: {"epoch": 99, "elapsed": 0.3546617490001154, "loss": 2.7198075300308906, }
# 22.728347 is the largest absolute weight in the embedding
# json_stats: {"epoch": 100, "elapsed": 0.26889425900026254, "loss": 2.7081012421309496, }
# 22.803301 is the largest absolute weight in the embedding
# json_stats: {"epoch": 101, "elapsed": 0.30374173400014115, "loss": 2.703029103994414, }
# 22.874909 is the largest absolute weight in the embedding
# json_stats: {"epoch": 102, "elapsed": 0.3249282910001057, "loss": 2.692684258697039, }
# 22.930506 is the largest absolute weight in the embedding
# json_stats: {"epoch": 103, "elapsed": 0.3034877949994552, "loss": 2.6803622991004787, }
# 23.005255 is the largest absolute weight in the embedding
# json_stats: {"epoch": 104, "elapsed": 0.2697023979999358, "loss": 2.672488937486975, }
# 23.044054 is the largest absolute weight in the embedding
# json_stats: {"epoch": 105, "elapsed": 0.33257862299979024, "loss": 2.662886608662075, }
# 23.097025 is the largest absolute weight in the embedding
# json_stats: {"epoch": 106, "elapsed": 0.4628280139995695, "loss": 2.6496661827740637, }
# 23.12729 is the largest absolute weight in the embedding
# json_stats: {"epoch": 107, "elapsed": 0.2923341519999667, "loss": 2.6503097260535897, }
# 23.147738 is the largest absolute weight in the embedding
# json_stats: {"epoch": 108, "elapsed": 0.5064467370002603, "loss": 2.6376825315627426, }
# 23.178318 is the largest absolute weight in the embedding
# json_stats: {"epoch": 109, "elapsed": 0.4291825259997495, "loss": 2.6269971224988296, }
# 23.222119 is the largest absolute weight in the embedding
# json_stats: {"epoch": 110, "elapsed": 0.46280168700013746, "loss": 2.6110099834850287, }
# 23.234252 is the largest absolute weight in the embedding
# json_stats: {"epoch": 111, "elapsed": 0.42008427400014625, "loss": 2.6054428526177884, }
# 23.274025 is the largest absolute weight in the embedding
# json_stats: {"epoch": 112, "elapsed": 0.4005252870001641, "loss": 2.596472173177025, }
# 23.281089 is the largest absolute weight in the embedding
# json_stats: {"epoch": 113, "elapsed": 0.6691265170002225, "loss": 2.5884938264993584, }
# 23.304728 is the largest absolute weight in the embedding
# json_stats: {"epoch": 114, "elapsed": 0.5737597529996492, "loss": 2.5791718284808436, }
# 23.307548 is the largest absolute weight in the embedding
# json_stats: {"epoch": 115, "elapsed": 0.5297090969997953, "loss": 2.570735387649105, }
# 23.334964 is the largest absolute weight in the embedding
# json_stats: {"epoch": 116, "elapsed": 0.6931839380004021, "loss": 2.565221992982119, }
# 23.338178 is the largest absolute weight in the embedding
# json_stats: {"epoch": 117, "elapsed": 0.4444860180001342, "loss": 2.551999754869543, }
# 23.352061 is the largest absolute weight in the embedding
# json_stats: {"epoch": 118, "elapsed": 0.5047118799993768, "loss": 2.546693879676179, }
# 23.358531 is the largest absolute weight in the embedding
# json_stats: {"epoch": 119, "elapsed": 0.3945662619998984, "loss": 2.5369649866769213, }
# 23.372565 is the largest absolute weight in the embedding
# json_stats: {"epoch": 120, "elapsed": 0.434130379000635, "loss": 2.529415677033974, }
# 23.38147 is the largest absolute weight in the embedding
# json_stats: {"epoch": 121, "elapsed": 0.464068227000098, "loss": 2.5180471714130594, }
# 23.378051 is the largest absolute weight in the embedding
# json_stats: {"epoch": 122, "elapsed": 0.38451570500001253, "loss": 2.5119502329032426, }
# 23.390431 is the largest absolute weight in the embedding
# json_stats: {"epoch": 123, "elapsed": 0.3396093840001413, "loss": 2.5007336554881596, }
# 23.393551 is the largest absolute weight in the embedding
# json_stats: {"epoch": 124, "elapsed": 0.42631065499972465, "loss": 2.4938291307154823, }
# 23.40275 is the largest absolute weight in the embedding
# json_stats: {"epoch": 125, "elapsed": 0.4618523050003205, "loss": 2.4852074838660996, }
# 23.404673 is the largest absolute weight in the embedding
# json_stats: {"epoch": 126, "elapsed": 0.369704611999623, "loss": 2.4769797127954694, }
# 23.40541 is the largest absolute weight in the embedding
# json_stats: {"epoch": 127, "elapsed": 0.45858893300010095, "loss": 2.4687167892789996, }
# 23.410129 is the largest absolute weight in the embedding
# json_stats: {"epoch": 128, "elapsed": 0.41528129400012403, "loss": 2.461019603641828, }
# 23.413003 is the largest absolute weight in the embedding
# json_stats: {"epoch": 129, "elapsed": 0.476383151999471, "loss": 2.44731778003932, }
# 23.415708 is the largest absolute weight in the embedding
# json_stats: {"epoch": 130, "elapsed": 0.5296368879999136, "loss": 2.440051792062057, }
# 23.419067 is the largest absolute weight in the embedding
# json_stats: {"epoch": 131, "elapsed": 0.3506099249998442, "loss": 2.4350253676148337, }
# 23.424155 is the largest absolute weight in the embedding
# json_stats: {"epoch": 132, "elapsed": 0.37356719900071766, "loss": 2.4298843670759354, }
# 23.424571 is the largest absolute weight in the embedding
# json_stats: {"epoch": 133, "elapsed": 0.5006940700004634, "loss": 2.419889762824393, }
# 23.42633 is the largest absolute weight in the embedding
# json_stats: {"epoch": 134, "elapsed": 0.4162671379999665, "loss": 2.4168842478242505, }
# 23.428754 is the largest absolute weight in the embedding
# json_stats: {"epoch": 135, "elapsed": 0.3207094959998358, "loss": 2.398849469095476, }
# 23.43305 is the largest absolute weight in the embedding
# json_stats: {"epoch": 136, "elapsed": 0.45732313799999247, "loss": 2.3941301861652784, }
# 23.432806 is the largest absolute weight in the embedding
# json_stats: {"epoch": 137, "elapsed": 0.3551930169996922, "loss": 2.381981576928147, }
# 23.436101 is the largest absolute weight in the embedding
# json_stats: {"epoch": 138, "elapsed": 0.5743339020000349, "loss": 2.371442958211615, }
# 23.437023 is the largest absolute weight in the embedding
# json_stats: {"epoch": 139, "elapsed": 0.41880816999946546, "loss": 2.3668792620794026, }
# 23.437938 is the largest absolute weight in the embedding
# json_stats: {"epoch": 140, "elapsed": 0.7616262550000101, "loss": 2.3576148656234945, }
# 23.438904 is the largest absolute weight in the embedding
# json_stats: {"epoch": 141, "elapsed": 0.5282256529999358, "loss": 2.3482769933012166, }
# 23.439259 is the largest absolute weight in the embedding
# json_stats: {"epoch": 142, "elapsed": 0.5739907799998036, "loss": 2.3363884768141063, }
# 23.439775 is the largest absolute weight in the embedding
# json_stats: {"epoch": 143, "elapsed": 0.6372741670002142, "loss": 2.3305740715849415, }
# 23.444194 is the largest absolute weight in the embedding
# json_stats: {"epoch": 144, "elapsed": 0.5840900020002664, "loss": 2.320241447063854, }
# 23.444502 is the largest absolute weight in the embedding
# json_stats: {"epoch": 145, "elapsed": 0.7472247550003885, "loss": 2.306580622709466, }
# 23.44279 is the largest absolute weight in the embedding
# json_stats: {"epoch": 146, "elapsed": 0.5868739819998154, "loss": 2.3097955199311815, }
# 23.442963 is the largest absolute weight in the embedding
# json_stats: {"epoch": 147, "elapsed": 0.3569583739999871, "loss": 2.295669646194206, }
# 23.443584 is the largest absolute weight in the embedding
# json_stats: {"epoch": 148, "elapsed": 0.6209817050003039, "loss": 2.2895520402454883, }
# 23.444596 is the largest absolute weight in the embedding
# json_stats: {"epoch": 149, "elapsed": 0.3383325499999046, "loss": 2.279347975598994, }
# 23.444721 is the largest absolute weight in the embedding
# json_stats: {"epoch": 150, "elapsed": 0.5371130350004023, "loss": 2.2788610930495823, }
# 23.445243 is the largest absolute weight in the embedding
# json_stats: {"epoch": 151, "elapsed": 0.48380738200012274, "loss": 2.2645231476417282, }
# 24.053847 is the largest absolute weight in the embedding
# json_stats: {"epoch": 152, "elapsed": 0.6428633320001609, "loss": 2.250546543149886, }
# 24.741704 is the largest absolute weight in the embedding
# json_stats: {"epoch": 153, "elapsed": 0.4779907510001067, "loss": 2.2464988980532596, }
# 25.404956 is the largest absolute weight in the embedding
# json_stats: {"epoch": 154, "elapsed": 0.5361518070003513, "loss": 2.238321113757284, }
# 26.002944 is the largest absolute weight in the embedding
# json_stats: {"epoch": 155, "elapsed": 0.4747546259995943, "loss": 2.2272501765465886, }
# 26.557737 is the largest absolute weight in the embedding
# json_stats: {"epoch": 156, "elapsed": 0.4428526340007011, "loss": 2.2204014802993965, }
# 27.017765 is the largest absolute weight in the embedding
# json_stats: {"epoch": 157, "elapsed": 0.392112196999733, "loss": 2.2189907808294618, }
# 27.403423 is the largest absolute weight in the embedding
# json_stats: {"epoch": 158, "elapsed": 0.4187944270006483, "loss": 2.205045781538654, }
# 27.775233 is the largest absolute weight in the embedding
# json_stats: {"epoch": 159, "elapsed": 0.3246222730003865, "loss": 2.1979648606277924, }
# 28.108742 is the largest absolute weight in the embedding
# json_stats: {"epoch": 160, "elapsed": 0.2981961470004535, "loss": 2.1824064553465172, }
# 28.447475 is the largest absolute weight in the embedding
# json_stats: {"epoch": 161, "elapsed": 0.34501030499995977, "loss": 2.1782812824438644, }
# 28.706602 is the largest absolute weight in the embedding
# json_stats: {"epoch": 162, "elapsed": 0.35793496099995536, "loss": 2.173585543541198, }
# 28.917399 is the largest absolute weight in the embedding
# json_stats: {"epoch": 163, "elapsed": 0.2875951329997406, "loss": 2.1609678949019298, }
# 29.113399 is the largest absolute weight in the embedding
# json_stats: {"epoch": 164, "elapsed": 0.3160033290005231, "loss": 2.158376380512913, }
# 29.277212 is the largest absolute weight in the embedding
# json_stats: {"epoch": 165, "elapsed": 0.2777776029997767, "loss": 2.138257453217819, }
# 29.42003 is the largest absolute weight in the embedding
# json_stats: {"epoch": 166, "elapsed": 0.29593703799946525, "loss": 2.1455856394022987, }
# 29.541701 is the largest absolute weight in the embedding
# json_stats: {"epoch": 167, "elapsed": 0.2976193250005963, "loss": 2.137131179816861, }
# 29.638009 is the largest absolute weight in the embedding
# json_stats: {"epoch": 168, "elapsed": 0.2715176120000251, "loss": 2.1221725441535844, }
# 29.75914 is the largest absolute weight in the embedding
# json_stats: {"epoch": 169, "elapsed": 0.2644360320000487, "loss": 2.116116105360966, }
# 29.845462 is the largest absolute weight in the embedding
# json_stats: {"epoch": 170, "elapsed": 0.23900821799998084, "loss": 2.101253941990068, }
# 29.910964 is the largest absolute weight in the embedding
# json_stats: {"epoch": 171, "elapsed": 0.3086055040002975, "loss": 2.104713900446541, }
# 29.992055 is the largest absolute weight in the embedding
# json_stats: {"epoch": 172, "elapsed": 0.33859294800004136, "loss": 2.094167072615781, }
# 30.054123 is the largest absolute weight in the embedding
# json_stats: {"epoch": 173, "elapsed": 0.2752609350000057, "loss": 2.08237023561663, }
# 30.099805 is the largest absolute weight in the embedding
# json_stats: {"epoch": 174, "elapsed": 0.2991946249994726, "loss": 2.0797436685506168, }
# 30.139319 is the largest absolute weight in the embedding
# json_stats: {"epoch": 175, "elapsed": 0.3008907209996323, "loss": 2.063667849272203, }
# 30.178734 is the largest absolute weight in the embedding
# json_stats: {"epoch": 176, "elapsed": 0.5440435739992608, "loss": 2.0590886678194242, }
# 30.208149 is the largest absolute weight in the embedding
# json_stats: {"epoch": 177, "elapsed": 0.8386646799999653, "loss": 2.053342802953947, }
# 30.238671 is the largest absolute weight in the embedding
# json_stats: {"epoch": 178, "elapsed": 0.38254278899967176, "loss": 2.033928127415418, }
# 30.264175 is the largest absolute weight in the embedding
# json_stats: {"epoch": 179, "elapsed": 0.3413929429998461, "loss": 2.0330918098292856, }
# 30.286804 is the largest absolute weight in the embedding
# json_stats: {"epoch": 180, "elapsed": 0.3533669970001938, "loss": 2.0163698454772936, }
# 30.307222 is the largest absolute weight in the embedding
# json_stats: {"epoch": 181, "elapsed": 0.3122927129998061, "loss": 2.012663963637106, }
# 30.324079 is the largest absolute weight in the embedding
# json_stats: {"epoch": 182, "elapsed": 0.28075605100002576, "loss": 1.9947018260282854, }
# 30.338811 is the largest absolute weight in the embedding
# json_stats: {"epoch": 183, "elapsed": 0.3146313030001693, "loss": 1.9814565883075532, }
# 30.353117 is the largest absolute weight in the embedding
# json_stats: {"epoch": 184, "elapsed": 0.2384157349997622, "loss": 1.986854152423747, }
# 30.366626 is the largest absolute weight in the embedding
# json_stats: {"epoch": 185, "elapsed": 0.32385023400001955, "loss": 1.9731517171587234, }
# 30.377484 is the largest absolute weight in the embedding
# json_stats: {"epoch": 186, "elapsed": 0.2968384010000591, "loss": 1.9580154923693698, }
# 30.38723 is the largest absolute weight in the embedding
# json_stats: {"epoch": 187, "elapsed": 0.26546592000067903, "loss": 1.9553339681155626, }
# 30.39514 is the largest absolute weight in the embedding
# json_stats: {"epoch": 188, "elapsed": 0.2692362689995207, "loss": 1.9494160067974113, }
# 30.40274 is the largest absolute weight in the embedding
# json_stats: {"epoch": 189, "elapsed": 0.2748781999998755, "loss": 1.937857364444762, }
# 30.410494 is the largest absolute weight in the embedding
# json_stats: {"epoch": 190, "elapsed": 0.3836318619996746, "loss": 1.9222971266552769, }
# 30.416696 is the largest absolute weight in the embedding
# json_stats: {"epoch": 191, "elapsed": 0.2378988450000179, "loss": 1.9177243205554246, }
# 30.422635 is the largest absolute weight in the embedding
# json_stats: {"epoch": 192, "elapsed": 0.25218618100007006, "loss": 1.9106649607704445, }
# 30.427532 is the largest absolute weight in the embedding
# json_stats: {"epoch": 193, "elapsed": 0.27069170999948255, "loss": 1.8963535445569668, }
# 30.43166 is the largest absolute weight in the embedding
# json_stats: {"epoch": 194, "elapsed": 0.29467235099946265, "loss": 1.887474790858865, }
# 30.435425 is the largest absolute weight in the embedding
# json_stats: {"epoch": 195, "elapsed": 0.2672353389998534, "loss": 1.8845411471656295, }
# 30.439028 is the largest absolute weight in the embedding
# json_stats: {"epoch": 196, "elapsed": 0.2669505459998618, "loss": 1.8842249083894302, }
# 30.442079 is the largest absolute weight in the embedding
# json_stats: {"epoch": 197, "elapsed": 0.29723201999968296, "loss": 1.8653653147755997, }
# 30.444346 is the largest absolute weight in the embedding
# json_stats: {"epoch": 198, "elapsed": 0.2702747659996021, "loss": 1.8531880626076416, }
# 30.447025 is the largest absolute weight in the embedding
# json_stats: {"epoch": 199, "elapsed": 0.2435324150001179, "loss": 1.8480236258488498, }
# 30.448939 is the largest absolute weight in the embedding
# json_stats: {"epoch": 200, "elapsed": 0.28671196600043913, "loss": 1.8427410272531375, }
# 30.450948 is the largest absolute weight in the embedding
# json_stats: {"epoch": 201, "elapsed": 0.30351085900019825, "loss": 1.8336943798777854, }
# 30.452941 is the largest absolute weight in the embedding
# json_stats: {"epoch": 202, "elapsed": 0.2638057080002909, "loss": 1.8188009569591794, }
# 30.454529 is the largest absolute weight in the embedding
# json_stats: {"epoch": 203, "elapsed": 0.2405224639996959, "loss": 1.8163558063862233, }
# 30.456063 is the largest absolute weight in the embedding
# json_stats: {"epoch": 204, "elapsed": 0.3229729770000631, "loss": 1.8061301679680615, }
# 30.457414 is the largest absolute weight in the embedding
# json_stats: {"epoch": 205, "elapsed": 0.2860341370005699, "loss": 1.7955634205449562, }
# 30.458549 is the largest absolute weight in the embedding
# json_stats: {"epoch": 206, "elapsed": 0.24933216800036462, "loss": 1.787184021578939, }
# 30.459555 is the largest absolute weight in the embedding
# json_stats: {"epoch": 207, "elapsed": 0.2820023519998358, "loss": 1.7810185825854254, }
# 30.460415 is the largest absolute weight in the embedding
# json_stats: {"epoch": 208, "elapsed": 0.2804097500002172, "loss": 1.7717186502535691, }
# 30.461231 is the largest absolute weight in the embedding
# json_stats: {"epoch": 209, "elapsed": 0.29594803399959346, "loss": 1.7589894971211106, }
# 30.462403 is the largest absolute weight in the embedding
# json_stats: {"epoch": 210, "elapsed": 0.26500508499975695, "loss": 1.7544941284890216, }
# 30.463099 is the largest absolute weight in the embedding
# json_stats: {"epoch": 211, "elapsed": 0.2742998000003354, "loss": 1.747309191868938, }
# 30.464057 is the largest absolute weight in the embedding
# json_stats: {"epoch": 212, "elapsed": 0.3165671079996173, "loss": 1.737454669756091, }
# 30.464623 is the largest absolute weight in the embedding
# json_stats: {"epoch": 213, "elapsed": 0.24616079499992338, "loss": 1.7291457694764392, }
# 30.465194 is the largest absolute weight in the embedding
# json_stats: {"epoch": 214, "elapsed": 0.2566122140005973, "loss": 1.7095232102693638, }
# 30.465768 is the largest absolute weight in the embedding
# json_stats: {"epoch": 215, "elapsed": 0.33252902399999584, "loss": 1.710765841631669, }
# 30.466294 is the largest absolute weight in the embedding
# json_stats: {"epoch": 216, "elapsed": 0.2767033910004102, "loss": 1.7021877277072144, }
# 30.466674 is the largest absolute weight in the embedding
# json_stats: {"epoch": 217, "elapsed": 0.2658519080005135, "loss": 1.690091073122333, }
# 30.467015 is the largest absolute weight in the embedding
# json_stats: {"epoch": 218, "elapsed": 0.2841487980003876, "loss": 1.6801333286526148, }
# 30.467332 is the largest absolute weight in the embedding
# json_stats: {"epoch": 219, "elapsed": 0.2667208009997921, "loss": 1.6749885467193621, }
# 30.467652 is the largest absolute weight in the embedding
# json_stats: {"epoch": 220, "elapsed": 0.26212827200015454, "loss": 1.6601677046756693, }
# 30.467897 is the largest absolute weight in the embedding
# json_stats: {"epoch": 221, "elapsed": 0.2667302789996029, "loss": 1.649231574238305, }
# 30.46815 is the largest absolute weight in the embedding
# json_stats: {"epoch": 222, "elapsed": 0.2834318329996677, "loss": 1.6387094731454643, }
# 30.468359 is the largest absolute weight in the embedding
# json_stats: {"epoch": 223, "elapsed": 0.2814901749998171, "loss": 1.6338381906617465, }
# 30.468524 is the largest absolute weight in the embedding
# json_stats: {"epoch": 224, "elapsed": 0.3030909099998098, "loss": 1.619332006974221, }
# 30.46868 is the largest absolute weight in the embedding
# json_stats: {"epoch": 225, "elapsed": 0.2806748400007564, "loss": 1.6116782085900967, }
# 34.982646 is the largest absolute weight in the embedding
# json_stats: {"epoch": 226, "elapsed": 0.30160183099997084, "loss": 1.5941423759664681, }
# 39.083011 is the largest absolute weight in the embedding
# json_stats: {"epoch": 227, "elapsed": 0.2582052739999199, "loss": 1.5903229385419684, }
# 43.451552 is the largest absolute weight in the embedding
# json_stats: {"epoch": 228, "elapsed": 0.2729008320002322, "loss": 1.5803145887572676, }
# 46.54067 is the largest absolute weight in the embedding
# json_stats: {"epoch": 229, "elapsed": 0.26941251900007046, "loss": 1.5700453705722432, }
# 48.433287 is the largest absolute weight in the embedding
# json_stats: {"epoch": 230, "elapsed": 0.27950428199983435, "loss": 1.563682068838803, }
# 50.515216 is the largest absolute weight in the embedding
# json_stats: {"epoch": 231, "elapsed": 0.3209277859996291, "loss": 1.5602565504869512, }
# 57.850142 is the largest absolute weight in the embedding
# json_stats: {"epoch": 232, "elapsed": 0.2644664810004542, "loss": 1.5389228100049117, }
# 64.86228 is the largest absolute weight in the embedding
# json_stats: {"epoch": 233, "elapsed": 0.30041352799980814, "loss": 1.534184746750384, }
# 71.756917 is the largest absolute weight in the embedding
# json_stats: {"epoch": 234, "elapsed": 0.2785673560001669, "loss": 1.5140822686405935, }
# 77.195948 is the largest absolute weight in the embedding
# json_stats: {"epoch": 235, "elapsed": 0.2723358269995515, "loss": 1.5043471598098408, }
# 81.767732 is the largest absolute weight in the embedding
# json_stats: {"epoch": 236, "elapsed": 0.2757257919993208, "loss": 1.5030737011836104, }
# 85.435969 is the largest absolute weight in the embedding
# json_stats: {"epoch": 237, "elapsed": 0.31481539200012776, "loss": 1.4913253394681931, }
# 88.125143 is the largest absolute weight in the embedding
# json_stats: {"epoch": 238, "elapsed": 0.2737384079991898, "loss": 1.4730342470498754, }
# 90.25464 is the largest absolute weight in the embedding
# json_stats: {"epoch": 239, "elapsed": 0.2374775670004965, "loss": 1.4663391117990134, }
# 91.933478 is the largest absolute weight in the embedding
# json_stats: {"epoch": 240, "elapsed": 0.31071995700040134, "loss": 1.4484462342583262, }
# 93.25735 is the largest absolute weight in the embedding
# json_stats: {"epoch": 241, "elapsed": 0.2683927260004566, "loss": 1.4439328594121676, }
# 94.272512 is the largest absolute weight in the embedding
# json_stats: {"epoch": 242, "elapsed": 0.246707473999777, "loss": 1.4339251013043268, }
# 94.973071 is the largest absolute weight in the embedding
# json_stats: {"epoch": 243, "elapsed": 0.27243671099950006, "loss": 1.4253911100903807, }
# 95.585095 is the largest absolute weight in the embedding
# json_stats: {"epoch": 244, "elapsed": 0.30626822800059017, "loss": 1.4147961351945777, }
# 96.068558 is the largest absolute weight in the embedding
# json_stats: {"epoch": 245, "elapsed": 0.3073370309994061, "loss": 1.4069990704427127, }
# 96.447799 is the largest absolute weight in the embedding
# json_stats: {"epoch": 246, "elapsed": 0.2529573039992101, "loss": 1.3901793738934964, }
# 96.763852 is the largest absolute weight in the embedding
# json_stats: {"epoch": 247, "elapsed": 0.26595649299997604, "loss": 1.3815716603875776, }
# 96.977303 is the largest absolute weight in the embedding
# json_stats: {"epoch": 248, "elapsed": 0.2975419399999737, "loss": 1.3645120530343242, }
# 97.166635 is the largest absolute weight in the embedding
# json_stats: {"epoch": 249, "elapsed": 0.26792192199991405, "loss": 1.3644905483666234, }
# 97.310013 is the largest absolute weight in the embedding
# json_stats: {"epoch": 250, "elapsed": 0.2668414700001449, "loss": 1.3546080546020947, }
# 97.414315 is the largest absolute weight in the embedding
# json_stats: {"epoch": 251, "elapsed": 0.29485339500024565, "loss": 1.3415760639333674, }
# 97.494899 is the largest absolute weight in the embedding
# json_stats: {"epoch": 252, "elapsed": 0.26640929099994537, "loss": 1.3304278794530433, }
# 97.559168 is the largest absolute weight in the embedding
# json_stats: {"epoch": 253, "elapsed": 0.2716150830001425, "loss": 1.3264259667944942, }
# 97.610063 is the largest absolute weight in the embedding
# json_stats: {"epoch": 254, "elapsed": 0.28387737899993226, "loss": 1.314552207061048, }
# 97.655134 is the largest absolute weight in the embedding
# json_stats: {"epoch": 255, "elapsed": 0.3100536279998778, "loss": 1.2979780918778305, }
# 97.692289 is the largest absolute weight in the embedding
# json_stats: {"epoch": 256, "elapsed": 0.25336979999974574, "loss": 1.2840450815555695, }
# 97.722659 is the largest absolute weight in the embedding
# json_stats: {"epoch": 257, "elapsed": 0.2706206900002144, "loss": 1.2833699005178676, }
# 97.745552 is the largest absolute weight in the embedding
# json_stats: {"epoch": 258, "elapsed": 0.2457249259996388, "loss": 1.2711513982167004, }
# 97.763898 is the largest absolute weight in the embedding
# json_stats: {"epoch": 259, "elapsed": 0.28119380899988755, "loss": 1.270031245461217, }
# 97.780835 is the largest absolute weight in the embedding
# json_stats: {"epoch": 260, "elapsed": 0.3342571780003709, "loss": 1.2631321899073933, }
# 97.794487 is the largest absolute weight in the embedding
# json_stats: {"epoch": 261, "elapsed": 0.2520813510000153, "loss": 1.2448844191572326, }
# 97.805634 is the largest absolute weight in the embedding
# json_stats: {"epoch": 262, "elapsed": 0.25572979799926543, "loss": 1.237556102688166, }
# 97.816654 is the largest absolute weight in the embedding
# json_stats: {"epoch": 263, "elapsed": 0.3194300810000641, "loss": 1.2244982758741838, }
# 97.824826 is the largest absolute weight in the embedding
# json_stats: {"epoch": 264, "elapsed": 0.318758598000386, "loss": 1.2213973481113782, }
# 97.831256 is the largest absolute weight in the embedding
# json_stats: {"epoch": 265, "elapsed": 0.28029476499978045, "loss": 1.208498327074099, }
# 97.836675 is the largest absolute weight in the embedding
# json_stats: {"epoch": 266, "elapsed": 0.3290789909997329, "loss": 1.2165085895207977, }
# 97.840823 is the largest absolute weight in the embedding
# json_stats: {"epoch": 267, "elapsed": 0.26598492700031784, "loss": 1.1969953146968302, }
# 97.844439 is the largest absolute weight in the embedding
# json_stats: {"epoch": 268, "elapsed": 0.27634371499971166, "loss": 1.1870181449144654, }
# 97.847975 is the largest absolute weight in the embedding
# json_stats: {"epoch": 269, "elapsed": 0.27752007999970374, "loss": 1.1831143520288212, }
# 97.851029 is the largest absolute weight in the embedding
# json_stats: {"epoch": 270, "elapsed": 0.300006193999252, "loss": 1.1690134820796614, }
# 97.853224 is the largest absolute weight in the embedding
# json_stats: {"epoch": 271, "elapsed": 0.2970859010001732, "loss": 1.1709684299170549, }
# 97.855498 is the largest absolute weight in the embedding
# json_stats: {"epoch": 272, "elapsed": 0.2858144479996554, "loss": 1.1551134828848468, }
# 97.857247 is the largest absolute weight in the embedding
# json_stats: {"epoch": 273, "elapsed": 0.297115119999944, "loss": 1.1495397655480575, }
# 97.858823 is the largest absolute weight in the embedding
# json_stats: {"epoch": 274, "elapsed": 0.3237242340001103, "loss": 1.134328331274332, }
# 97.860069 is the largest absolute weight in the embedding
# json_stats: {"epoch": 275, "elapsed": 0.261833137999929, "loss": 1.1328687881547381, }
# 97.861151 is the largest absolute weight in the embedding
# json_stats: {"epoch": 276, "elapsed": 0.2533543979998285, "loss": 1.1250871233058952, }
# 97.862041 is the largest absolute weight in the embedding
# json_stats: {"epoch": 277, "elapsed": 0.29896810600075696, "loss": 1.1206578105621758, }
# 97.86285 is the largest absolute weight in the embedding
# json_stats: {"epoch": 278, "elapsed": 0.28561446799994883, "loss": 1.1127845417750521, }
# 97.863392 is the largest absolute weight in the embedding
# json_stats: {"epoch": 279, "elapsed": 0.23177147099977446, "loss": 1.1092778609703338, }
# 97.863955 is the largest absolute weight in the embedding
# json_stats: {"epoch": 280, "elapsed": 0.2899216770001658, "loss": 1.102000720147192, }
# 97.864425 is the largest absolute weight in the embedding
# json_stats: {"epoch": 281, "elapsed": 0.3090411879993553, "loss": 1.0860035952449092, }
# 97.864879 is the largest absolute weight in the embedding
# json_stats: {"epoch": 282, "elapsed": 0.2568865100001858, "loss": 1.0826870077583635, }
# 97.8653 is the largest absolute weight in the embedding
# json_stats: {"epoch": 283, "elapsed": 0.25586844100052986, "loss": 1.0757896989693674, }
# 97.865601 is the largest absolute weight in the embedding
# json_stats: {"epoch": 284, "elapsed": 0.3022203869995792, "loss": 1.071206867296859, }
# 97.865871 is the largest absolute weight in the embedding
# json_stats: {"epoch": 285, "elapsed": 0.2661481670002104, "loss": 1.0701817191516185, }
# 97.866131 is the largest absolute weight in the embedding
# json_stats: {"epoch": 286, "elapsed": 0.26063325999984954, "loss": 1.0478975692444366, }
# 97.866343 is the largest absolute weight in the embedding
# json_stats: {"epoch": 287, "elapsed": 0.2633640869998999, "loss": 1.042623011864005, }
# 97.866535 is the largest absolute weight in the embedding
# json_stats: {"epoch": 288, "elapsed": 0.2638081470004181, "loss": 1.050956235003554, }
# 97.866726 is the largest absolute weight in the embedding
# json_stats: {"epoch": 289, "elapsed": 0.32314643599966075, "loss": 1.0314102596144794, }
# 97.866895 is the largest absolute weight in the embedding
# json_stats: {"epoch": 290, "elapsed": 0.2592597470002147, "loss": 1.029703696327363, }
# 97.867023 is the largest absolute weight in the embedding
# json_stats: {"epoch": 291, "elapsed": 0.260987589999786, "loss": 1.0217555249645864, }
# 97.867156 is the largest absolute weight in the embedding
# json_stats: {"epoch": 292, "elapsed": 0.3128467630003797, "loss": 1.0224362977321453, }
# 97.867255 is the largest absolute weight in the embedding
# json_stats: {"epoch": 293, "elapsed": 0.2825139010001294, "loss": 1.0204157670825713, }
# 97.86736 is the largest absolute weight in the embedding
# json_stats: {"epoch": 294, "elapsed": 0.23613539100006165, "loss": 1.001990277558985, }
# 97.867446 is the largest absolute weight in the embedding
# json_stats: {"epoch": 295, "elapsed": 0.24898238200057676, "loss": 1.0053089986758517, }
# 97.867512 is the largest absolute weight in the embedding
# json_stats: {"epoch": 296, "elapsed": 0.3062559780000811, "loss": 0.9999866427523384, }
# 97.867572 is the largest absolute weight in the embedding
# json_stats: {"epoch": 297, "elapsed": 0.24937197100007324, "loss": 0.983838567067756, }
# 97.867622 is the largest absolute weight in the embedding
# json_stats: {"epoch": 298, "elapsed": 0.2653214880001542, "loss": 0.9885074339131855, }
# 97.867676 is the largest absolute weight in the embedding
# json_stats: {"epoch": 299, "elapsed": 0.29767632499988395, "loss": 0.9742385907335119, }
# 97.867725 is the largest absolute weight in the embedding
# json_stats: {"epoch": 300, "elapsed": 0.28699821700047323, "loss": 0.9610903866445408, }
# 97.867765 is the largest absolute weight in the embedding
# json_stats: {"epoch": 301, "elapsed": 0.30066237099981663, "loss": 0.9616182427536677, }
# 97.867802 is the largest absolute weight in the embedding
# json_stats: {"epoch": 302, "elapsed": 0.27959282099982374, "loss": 0.9570651886316621, }
# 97.867833 is the largest absolute weight in the embedding
# json_stats: {"epoch": 303, "elapsed": 0.27953642299962667, "loss": 0.9591973542552659, }
# 97.86786 is the largest absolute weight in the embedding
# json_stats: {"epoch": 304, "elapsed": 0.2813478699999905, "loss": 0.9521959369898408, }
# 97.867886 is the largest absolute weight in the embedding
# json_stats: {"epoch": 305, "elapsed": 0.2741827870004272, "loss": 0.9417758967140136, }
# 97.867906 is the largest absolute weight in the embedding
# json_stats: {"epoch": 306, "elapsed": 0.30047135099994193, "loss": 0.9372392140044191, }
# 97.867925 is the largest absolute weight in the embedding
# json_stats: {"epoch": 307, "elapsed": 0.324563262999618, "loss": 0.9392740329917793, }
# 97.867943 is the largest absolute weight in the embedding
# json_stats: {"epoch": 308, "elapsed": 0.23667211399970256, "loss": 0.915372931626808, }
# 97.867961 is the largest absolute weight in the embedding
# json_stats: {"epoch": 309, "elapsed": 0.2936883390002549, "loss": 0.921175879398858, }
# 97.867975 is the largest absolute weight in the embedding
# json_stats: {"epoch": 310, "elapsed": 0.272156650999932, "loss": 0.9195665146682972, }
# 97.867988 is the largest absolute weight in the embedding
# json_stats: {"epoch": 311, "elapsed": 0.2939006119995611, "loss": 0.9213165852322087, }
# 97.867998 is the largest absolute weight in the embedding
# json_stats: {"epoch": 312, "elapsed": 0.271002296000006, "loss": 0.9029163513089671, }
# 97.868008 is the largest absolute weight in the embedding
# json_stats: {"epoch": 313, "elapsed": 0.24690585799999099, "loss": 0.8993855167768702, }
# 97.868016 is the largest absolute weight in the embedding
# json_stats: {"epoch": 314, "elapsed": 0.32331059600073786, "loss": 0.8901961365044785, }
# 97.868024 is the largest absolute weight in the embedding
# json_stats: {"epoch": 315, "elapsed": 0.23924338300003, "loss": 0.8945308514256406, }
# 97.868031 is the largest absolute weight in the embedding
# json_stats: {"epoch": 316, "elapsed": 0.23107353300019895, "loss": 0.8940730027086278, }
# 97.868038 is the largest absolute weight in the embedding
# json_stats: {"epoch": 317, "elapsed": 0.31726893999984895, "loss": 0.8790049066104884, }
# 97.868044 is the largest absolute weight in the embedding
# json_stats: {"epoch": 318, "elapsed": 0.2839208810000855, "loss": 0.8808686374426147, }
# 97.868051 is the largest absolute weight in the embedding
# json_stats: {"epoch": 319, "elapsed": 0.26683507399957307, "loss": 0.8716115555357157, }
# 97.868055 is the largest absolute weight in the embedding
# json_stats: {"epoch": 320, "elapsed": 0.32158450599945354, "loss": 0.867701014738205, }
# 97.868059 is the largest absolute weight in the embedding
# json_stats: {"epoch": 321, "elapsed": 0.28631862699967314, "loss": 0.8614948318551647, }
# 97.868064 is the largest absolute weight in the embedding
# json_stats: {"epoch": 322, "elapsed": 0.29806534399995144, "loss": 0.8642450554856845, }
# 97.868067 is the largest absolute weight in the embedding
# json_stats: {"epoch": 323, "elapsed": 0.27073374900010094, "loss": 0.8486637919697027, }
# 97.868071 is the largest absolute weight in the embedding
# json_stats: {"epoch": 324, "elapsed": 0.2816176650003399, "loss": 0.8479903608796817, }
# 97.868073 is the largest absolute weight in the embedding
# json_stats: {"epoch": 325, "elapsed": 0.3020318600001701, "loss": 0.8395713074022919, }
# 97.868075 is the largest absolute weight in the embedding
# json_stats: {"epoch": 326, "elapsed": 0.33054164799978025, "loss": 0.8404344171870826, }
# 97.868078 is the largest absolute weight in the embedding
# json_stats: {"epoch": 327, "elapsed": 0.27660261199980596, "loss": 0.8402835963719514, }
# 97.86808 is the largest absolute weight in the embedding
# json_stats: {"epoch": 328, "elapsed": 0.32233688500036806, "loss": 0.8383914648891134, }
# ...
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 892, "elapsed": 0.29262483099955716, "loss": 0.23251096403307944, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 893, "elapsed": 0.2972274200001266, "loss": 0.23270091605970594, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 894, "elapsed": 0.30635976400026266, "loss": 0.23109431382097187, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 895, "elapsed": 0.3379346890005763, "loss": 0.23304657323023414, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 896, "elapsed": 0.2866573170003903, "loss": 0.2286420966686374, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 897, "elapsed": 0.3261721970002327, "loss": 0.2345758018397438, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 898, "elapsed": 0.3133830910001052, "loss": 0.23321369825850696, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 899, "elapsed": 0.31973952099997405, "loss": 0.2321753134902621, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 900, "elapsed": 0.31408707899936417, "loss": 0.23113206798012947, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 901, "elapsed": 0.32437458200001856, "loss": 0.23112988913779925, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 902, "elapsed": 0.33540929200080427, "loss": 0.22907059789855408, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 903, "elapsed": 0.3211099509999258, "loss": 0.22610550725101208, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 904, "elapsed": 0.3879065930004799, "loss": 0.23248662173915136, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 905, "elapsed": 0.3139054679995752, "loss": 0.22963122201040234, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 906, "elapsed": 0.3253648809995866, "loss": 0.23157610386023839, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 907, "elapsed": 0.3030553210001017, "loss": 0.23046342362304775, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 908, "elapsed": 0.32706385100027546, "loss": 0.22718296956409717, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 909, "elapsed": 0.39347490000000107, "loss": 0.2276792432981666, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 910, "elapsed": 0.34179791000042314, "loss": 0.22987209503803172, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 911, "elapsed": 0.2672413139998753, "loss": 0.22806172781674702, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 912, "elapsed": 0.35631429499972, "loss": 0.2318719414070518, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 913, "elapsed": 0.33955146500011324, "loss": 0.2282926900962169, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 914, "elapsed": 0.32952273200044147, "loss": 0.22881666580586638, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 915, "elapsed": 0.29206855299980816, "loss": 0.22912305339555405, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 916, "elapsed": 0.34613767600058054, "loss": 0.22573608710120477, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 917, "elapsed": 0.31619700899955205, "loss": 0.22941718135645284, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 918, "elapsed": 0.3444762239996635, "loss": 0.22830736006360142, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 919, "elapsed": 0.33981675199993333, "loss": 0.22782061865034237, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 920, "elapsed": 0.30431182400025136, "loss": 0.2258067720371429, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 921, "elapsed": 0.332816532999459, "loss": 0.2246871359993561, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 922, "elapsed": 0.3543245199998637, "loss": 0.22450711927387682, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 923, "elapsed": 0.38700661799975933, "loss": 0.23016615844356633, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 924, "elapsed": 0.3263685540005099, "loss": 0.2247369371825833, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 925, "elapsed": 0.32856944300056057, "loss": 0.22686265709743694, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 926, "elapsed": 0.2905275920002168, "loss": 0.22508436291489467, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 927, "elapsed": 0.3179470479999509, "loss": 0.22211745931165242, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 928, "elapsed": 0.3279766050000035, "loss": 0.22179222003825036, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 929, "elapsed": 0.2873526449993733, "loss": 0.22789896357854061, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 930, "elapsed": 0.31179980599972623, "loss": 0.22221457830313995, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 931, "elapsed": 0.30171956499998487, "loss": 0.22286461720995895, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 932, "elapsed": 0.33234503400035464, "loss": 0.22632219065295156, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 933, "elapsed": 0.3331398599993918, "loss": 0.22128454597371225, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 934, "elapsed": 0.3150564210000084, "loss": 0.22408863784923683, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 935, "elapsed": 0.3494115130006321, "loss": 0.22356287657587443, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 936, "elapsed": 0.3222619649995977, "loss": 0.22369497741609273, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 937, "elapsed": 0.30684697600008803, "loss": 0.22353029069110483, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 938, "elapsed": 0.3588358090000838, "loss": 0.2247366272889406, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 939, "elapsed": 0.2881598979993214, "loss": 0.22023663663260984, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 940, "elapsed": 0.2875323299995216, "loss": 0.2189798468083948, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 941, "elapsed": 0.35536344699994515, "loss": 0.2226418431563107, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 942, "elapsed": 0.3130513599999176, "loss": 0.21631077739695398, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 943, "elapsed": 0.3755205429997659, "loss": 0.2244861748893624, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 944, "elapsed": 0.4010714039995946, "loss": 0.22662097891900615, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 945, "elapsed": 0.3591561630000797, "loss": 0.22546786908664376, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 946, "elapsed": 0.26928169900020293, "loss": 0.2226677793190762, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 947, "elapsed": 0.2973177100002431, "loss": 0.21983494909319548, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 948, "elapsed": 0.2955381249994389, "loss": 0.22482507056295198, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 949, "elapsed": 0.2912609889999658, "loss": 0.22272686124370858, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 950, "elapsed": 0.3278706460005196, "loss": 0.22044778691548392, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 951, "elapsed": 0.35299354000017047, "loss": 0.2262385144241315, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 952, "elapsed": 0.27915580500030046, "loss": 0.22069989793499917, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 953, "elapsed": 0.3174144399999932, "loss": 0.21963131395980764, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 954, "elapsed": 0.3225103720005791, "loss": 0.22139072651789382, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 955, "elapsed": 0.3406676120002885, "loss": 0.21917470872433645, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 956, "elapsed": 0.33817990599982295, "loss": 0.21986619103728558, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 957, "elapsed": 0.34490352099965094, "loss": 0.2214193374813417, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 958, "elapsed": 0.2860342829999354, "loss": 0.21542388816911998, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 959, "elapsed": 0.3040799139998853, "loss": 0.2186012760738376, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 960, "elapsed": 0.36680365900065226, "loss": 0.21812623102031523, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 961, "elapsed": 0.29151589299999614, "loss": 0.2189023821219683, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 962, "elapsed": 0.2883159319999322, "loss": 0.21599353349442657, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 963, "elapsed": 0.3758649590008645, "loss": 0.21729463443174413, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 964, "elapsed": 0.2814757490004922, "loss": 0.21836320596680486, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 965, "elapsed": 0.26829243900010624, "loss": 0.21720940591152002, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 966, "elapsed": 0.35458139999991545, "loss": 0.22038574498903157, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 967, "elapsed": 0.3043119080002725, "loss": 0.21552109253950658, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 968, "elapsed": 0.283878872999594, "loss": 0.21721448652804468, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 969, "elapsed": 0.3511938870005906, "loss": 0.21947442590546368, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 970, "elapsed": 0.3399575660005212, "loss": 0.21734164100718437, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 971, "elapsed": 0.3351865370004816, "loss": 0.21679993137059167, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 972, "elapsed": 0.30262066300019796, "loss": 0.21625101407977113, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 973, "elapsed": 0.3565144539998073, "loss": 0.21685389060922466, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 974, "elapsed": 0.30245718699916324, "loss": 0.21821514872932463, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 975, "elapsed": 0.28332275400043727, "loss": 0.2188901109967766, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 976, "elapsed": 0.3660501340000337, "loss": 0.2174940565873192, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 977, "elapsed": 0.2927099759999692, "loss": 0.21689720812891697, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 978, "elapsed": 0.31382044500060147, "loss": 0.2155218220646162, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 979, "elapsed": 0.3108069150002848, "loss": 0.21738281998057757, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 980, "elapsed": 0.33732509699984803, "loss": 0.2168356212572489, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 981, "elapsed": 0.2960957289997168, "loss": 0.2146422097578893, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 982, "elapsed": 0.31776408800033096, "loss": 0.21627540541870258, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 983, "elapsed": 0.29137273600008484, "loss": 0.21280908292470144, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 984, "elapsed": 0.30678948599961586, "loss": 0.21339295660523513, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 985, "elapsed": 0.30510631400011334, "loss": 0.2126013156862406, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 986, "elapsed": 0.33950611599993863, "loss": 0.21595737711560442, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 987, "elapsed": 0.3207411019993742, "loss": 0.2165670327585362, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 988, "elapsed": 0.27777816699926916, "loss": 0.21537000294295533, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 989, "elapsed": 0.3404660559999684, "loss": 0.21418040050036852, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 990, "elapsed": 0.2983232289998341, "loss": 0.21174848802288615, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 991, "elapsed": 0.2980912579996584, "loss": 0.21500527275414424, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 992, "elapsed": 0.3372989770005006, "loss": 0.21495146041806143, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 993, "elapsed": 0.3485348410004008, "loss": 0.2136616093189017, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 994, "elapsed": 0.3024863059999916, "loss": 0.2144284742234368, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 995, "elapsed": 0.2877766439996776, "loss": 0.21414152477124948, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 996, "elapsed": 0.32419283299987, "loss": 0.21283042668192229, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 997, "elapsed": 0.27080505800040555, "loss": 0.2133547359839429, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 998, "elapsed": 0.36006571100006113, "loss": 0.21261768855875623, }
# 97.868103 is the largest absolute weight in the embedding
# json_stats: {"epoch": 999, "elapsed": 0.282211556999755, "loss": 0.21392051214293506, }
# Total training time is: 308.9203050590004

# %% [markdown]
# # Evaluate embedding

# %%
model_weight = model.lt.weight.clone()
meanrank, maprank = eval_reconstruction(adj, model_weight, 
                                        manifold.distance, workers=opt_ndproc)
sqnorms = manifold.pnorm(model_weight)
sqnorm_min = sqnorms.min().item()
sqnorm_avg = sqnorms.mean().item()
sqnorm_max = sqnorms.max().item()
eval_res = [meanrank, maprank, sqnorm_min, sqnorm_avg, sqnorm_max, train_time]
RESULTS = RES(loss, eval_res, model_weight)
torch.save(RESULTS, "./results_weights/"+FILE_NAME+"_seed1"+ ".pt")
log.info(
    'json_stats final test: \n{'
    f'"sqnorm_min": {round(sqnorm_min,6)}, '
    f'"sqnorm_avg": {round(sqnorm_avg,6)}, '
    f'"sqnorm_max": {round(sqnorm_max,6)}, \n'
    f'"mean_rank": {round(meanrank,6)}, '
    f'"map": {round(maprank,6)}, '
    '}'
)
print(model.lt.weight.data[0])
# Out:
# json_stats final test:
# {"sqnorm_min": 0.384906, "sqnorm_avg": 0.998911, "sqnorm_max": 1.0,
# "mean_rank": 1.548318, "map": 0.910576, }
# tensor([1.9570e+00, 2.5072e-11])

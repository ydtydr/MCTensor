# %% [markdown]
# ## MCTensor Poincare Halfspace embedding for the WordNet Mammals dataset

# %%
# srun --pty --gres=gpu:3090:1 bash
import timeit
import torch
from tqdm import tqdm
import numpy as np
import logging
from hype.sn import Embedding, MCEmbedding
from hype import train
from hype.graph import load_edge_list, eval_reconstruction
from hype.rsgd import MCRiemannianSGD
from hype.Halfspace import HalfspaceManifold
from hype.MC_Halfspace import MC_HalfspaceManifold
import sys, os, random
import json
import torch.multiprocessing as mp
from hype.graph_dataset import BatchedDataset
os.environ["NUMEXPR_MAX_THREADS"] = '8'

def seed_everything(seed=1234):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

d16 = torch.float16; d32 = torch.float32; d64 = torch.float64
cpu = torch.device("cpu"); gpu = torch.device(type='cuda', index=0)
device = cpu
# torch.set_default_tensor_type('torch.DoubleTensor')
#torch.set_default_tensor_type('torch.HalfTensor')
torch.manual_seed(42)
np.random.seed(42)
# Out:
# /home/canal/anaconda3/envs/MCF_hyperbolic/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Set the number of components (nc) in the cell below:

# %%
opt_nc = 2

# %% [markdown]
# ### Hyperparameters for MCTensor Poincare Halfspace model:

# %%
## parameters; these are global in the notebook!
opt_maxnorm = 500000; opt_debug = False;
opt_dim = 2; opt_com_n = 1;
opt_negs = 50;  opt_eval_each = 20;
opt_sparse = True; opt_ndproc = 1;  opt_burnin = 20;
opt_dampening = 0.75; opt_neg_multiplier = 1.0; 
opt_burnin_multiplier = 0.01; 
###########################################################
opt_epochs = 1000; opt_batchsize = 32; 
opt_lr = 1.7;  opt_dscale = 0.3
opt_task = 'mammals'; opt_manifold = "MC_Halfspace";  opt_dtype = d64
#######################################
if opt_dtype == d16:
    dtype = "d16"
elif opt_dtype == d32:
    dtype = "d32"
else:
    dtype = "d64"
#######################################
FILE_NAME = "_".join([opt_task, 'lr', str(opt_lr), 'batch', str(opt_batchsize),
                      str(opt_epochs), "MC", dtype, "nc"+str(opt_nc), str(opt_dscale)])

# %%
MANIFOLDS = {
    'Halfspace': HalfspaceManifold,
    'MC_Halfspace': MC_HalfspaceManifold,
}

class RES():
    def __init__(self, loss, eval_res, weight):
        self.loss = torch.tensor(loss, dtype=torch.float64, 
                                 device=cpu)
        self.eval_res = torch.tensor(eval_res, dtype=torch.float64, 
                                     device=cpu)
        self.weight = weight

# %% [markdown]
# ### Initializing logging and data loading

# %%
log_level = logging.DEBUG if opt_debug else logging.INFO
log = logging.getLogger('MCF')
logging.basicConfig(level=log_level, format='%(message)s', stream=sys.stdout)
log.info('Using edge list dataloader')
idx, objects, weights = load_edge_list("wordnet/mammal_closure.csv", False)
# Out:
# Using edge list dataloader

# %% [markdown]
# ### Initializing model

# %%
def init_model(manifold, idx, objects, weights, nc=2, sparse=True, dtype=d64):
    conf = []
    model_name = '%s_dim%d%com_n'
    mname = model_name % (opt_manifold, opt_dim, opt_com_n)
    data = BatchedDataset(idx, objects, weights, opt_negs, opt_batchsize,
                          opt_ndproc, opt_burnin > 0, opt_dampening)
    model = MCEmbedding(len(data.objects), opt_dim, manifold,
                        nc=nc, sparse=sparse, com_n=opt_com_n, device=device,
                        dtype=dtype)
    data.objects = objects
    return model, data, mname, conf


def adj_matrix(data):
    adj = {}
    for inputs, _ in data:
        for row in inputs:
            x = row[0].item()
            y = row[1].item()
            if x in adj:
                adj[x].add(y)
            else:
                adj[x] = {y}
    return adj

# %% [markdown]
# ### Training

# %%
def data_loader_lr(data, epoch, progress=False):
    data.burnin = False
    lr = opt_lr
    if epoch < opt_burnin:
        data.burnin = True
        lr = opt_lr * train._lr_multiplier
    loader_iter = tqdm(data) if progress else data
    return loader_iter, lr

# %%
def train(device, model, data, optimizer, progress=False):
    epoch_loss = torch.Tensor(len(data))
    LOSS = np.zeros(opt_epochs)

    for epoch in range(opt_epochs):
        largest_weight_emb = round(
            torch.abs(model.lt.weight.data).max().item(), 6)
        print(largest_weight_emb, "is the largest absolute weight in the embedding")

        epoch_loss.fill_(0)
        t_start = timeit.default_timer()
        # handling burnin, get loader_iter and learning rate
        loader_iter, lr = data_loader_lr(data, epoch, progress=progress)

        for i_batch, (inputs, targets) in enumerate(loader_iter):
            elapsed = timeit.default_timer() - t_start
            inputs = inputs.to(device)
            targets = targets.to(device)
            optimizer.zero_grad()
            preds = model(inputs) * opt_dscale
            loss = model.loss(preds, targets, size_average=True)
            loss.backward()
            optimizer.step(lr=lr)
            with torch.no_grad():
                loss = model.loss(preds.to(d64), targets, size_average=True)
                epoch_loss[i_batch] = loss.cpu().item()
            #print("i:", i_batch, "loss:", epoch_loss[i_batch])

        LOSS[epoch] = torch.mean(epoch_loss).to(d64).item()
        # since only one thread is used:
        log.info('json_stats: {' f'"epoch": {epoch}, '
                 f'"elapsed": {elapsed}, ' f'"loss": {LOSS[epoch]}, ' '}')
    return LOSS

# %% [markdown]
# # Training embedding

# %%
# setup model
seed_everything(1)
manifold = MANIFOLDS[opt_manifold](
        debug=opt_debug, max_norm=opt_maxnorm, com_n=opt_com_n)
model, data, model_name, conf = init_model(
    manifold, idx, objects, weights, nc=opt_nc, sparse=opt_sparse, dtype=opt_dtype)
data.neg_multiplier = opt_neg_multiplier
train._lr_multiplier = opt_burnin_multiplier
print('the total dimension', model.lt.weight.size(-1), 'com_n', opt_com_n)
print(">>>>>> # MCTensor# | dtype is:", model.lt.weight.dtype,
              "| device is:", model.lt.weight.device, 
              "| nc is:", model.lt.weight.size_nc(-1))
# setup optimizer
optimizer = MCRiemannianSGD(model.optim_params(manifold), lr= opt_lr)
# get adjacency matrix
adj = adj_matrix(data) 
# begin training
start_time = timeit.default_timer()
loss = train(device, model, data, optimizer, progress=False )
train_time = timeit.default_timer() - start_time
print("Total training time is:", train_time)
# Out:
# /tmp/ipykernel_2466/3405949701.py:5: DeprecationWarning: `np.long` is a deprecated alias for `np.compat.long`. To silence this warning, use `np.compat.long` by itself. In the likely event your code does not need to work on Python 2 you can use the builtin `int` for which `np.compat.long` is itself an alias. Doing this will not modify any behaviour and is safe. When replacing `np.long`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data = BatchedDataset(idx, objects, weights, opt_negs, opt_batchsize,
# >>>>>> The size of MCHypEmbedding: 1180, 2, sparse=True
# the total dimension 2 com_n 1
# >>>>>> # MCTensor# | dtype is: torch.float64 | device is: cpu | nc is: 2
# 1.0001 is the largest absolute weight in the embedding
# json_stats: {"epoch": 0, "elapsed": 4.55822560799993, "loss": 3.9317076206207275, }
# 1.003987 is the largest absolute weight in the embedding
# json_stats: {"epoch": 1, "elapsed": 4.420554923000054, "loss": 3.93137264251709, }
# 1.007866 is the largest absolute weight in the embedding
# json_stats: {"epoch": 2, "elapsed": 4.431728612000143, "loss": 3.931032657623291, }
# 1.011775 is the largest absolute weight in the embedding
# json_stats: {"epoch": 3, "elapsed": 4.725710367000147, "loss": 3.930691957473755, }
# 1.015683 is the largest absolute weight in the embedding
# json_stats: {"epoch": 4, "elapsed": 4.586589875000072, "loss": 3.9303460121154785, }
# 1.019605 is the largest absolute weight in the embedding
# json_stats: {"epoch": 5, "elapsed": 4.517001459000085, "loss": 3.930006742477417, }
# 1.023515 is the largest absolute weight in the embedding
# json_stats: {"epoch": 6, "elapsed": 4.4379012619999685, "loss": 3.9296650886535645, }
# 1.027392 is the largest absolute weight in the embedding
# json_stats: {"epoch": 7, "elapsed": 4.578735383999856, "loss": 3.929318428039551, }
# 1.031328 is the largest absolute weight in the embedding
# json_stats: {"epoch": 8, "elapsed": 4.473278116000074, "loss": 3.928983688354492, }
# 1.035262 is the largest absolute weight in the embedding
# json_stats: {"epoch": 9, "elapsed": 4.411204468000051, "loss": 3.9286298751831055, }
# 1.039195 is the largest absolute weight in the embedding
# json_stats: {"epoch": 10, "elapsed": 4.568239502000097, "loss": 3.9282803535461426, }
# 1.043172 is the largest absolute weight in the embedding
# json_stats: {"epoch": 11, "elapsed": 4.388632161000032, "loss": 3.9279391765594482, }
# 1.047147 is the largest absolute weight in the embedding
# json_stats: {"epoch": 12, "elapsed": 4.498067616000071, "loss": 3.9275951385498047, }
# 1.051126 is the largest absolute weight in the embedding
# json_stats: {"epoch": 13, "elapsed": 4.42493786, "loss": 3.9272496700286865, }
# 1.054846 is the largest absolute weight in the embedding
# json_stats: {"epoch": 14, "elapsed": 4.606527324999888, "loss": 3.926900625228882, }
# 1.058837 is the largest absolute weight in the embedding
# json_stats: {"epoch": 15, "elapsed": 4.546578774999944, "loss": 3.926555633544922, }
# 1.062747 is the largest absolute weight in the embedding
# json_stats: {"epoch": 16, "elapsed": 4.415254356000105, "loss": 3.9262118339538574, }
# 1.066759 is the largest absolute weight in the embedding
# json_stats: {"epoch": 17, "elapsed": 4.532037281000157, "loss": 3.9258673191070557, }
# 1.070816 is the largest absolute weight in the embedding
# json_stats: {"epoch": 18, "elapsed": 4.50785092000001, "loss": 3.9255270957946777, }
# 1.074865 is the largest absolute weight in the embedding
# json_stats: {"epoch": 19, "elapsed": 4.557392500000105, "loss": 3.925163745880127, }
# 1.079009 is the largest absolute weight in the embedding
# json_stats: {"epoch": 20, "elapsed": 5.16467184499993, "loss": 3.926163911819458, }
# 1.147344 is the largest absolute weight in the embedding
# json_stats: {"epoch": 21, "elapsed": 4.958424703999981, "loss": 3.9088099002838135, }
# 1.302017 is the largest absolute weight in the embedding
# json_stats: {"epoch": 22, "elapsed": 4.943892569000127, "loss": 3.8908352851867676, }
# 1.386154 is the largest absolute weight in the embedding
# json_stats: {"epoch": 23, "elapsed": 4.989477257999852, "loss": 3.8716611862182617, }
# 1.532609 is the largest absolute weight in the embedding
# json_stats: {"epoch": 24, "elapsed": 4.858989746000134, "loss": 3.8526651859283447, }
# 1.689296 is the largest absolute weight in the embedding
# json_stats: {"epoch": 25, "elapsed": 4.8194453459998385, "loss": 3.8337771892547607, }
# 1.860842 is the largest absolute weight in the embedding
# json_stats: {"epoch": 26, "elapsed": 4.866980216999991, "loss": 3.8147597312927246, }
# 2.020788 is the largest absolute weight in the embedding
# json_stats: {"epoch": 27, "elapsed": 5.118255467000154, "loss": 3.7961716651916504, }
# 2.21454 is the largest absolute weight in the embedding
# json_stats: {"epoch": 28, "elapsed": 4.976122198999974, "loss": 3.7777140140533447, }
# 2.441741 is the largest absolute weight in the embedding
# json_stats: {"epoch": 29, "elapsed": 4.898272281000118, "loss": 3.7588584423065186, }
# 2.669457 is the largest absolute weight in the embedding
# json_stats: {"epoch": 30, "elapsed": 4.923826399000063, "loss": 3.74027156829834, }
# 2.898638 is the largest absolute weight in the embedding
# json_stats: {"epoch": 31, "elapsed": 5.0239457309999125, "loss": 3.72235107421875, }
# 3.179628 is the largest absolute weight in the embedding
# json_stats: {"epoch": 32, "elapsed": 5.0271467239999765, "loss": 3.7039318084716797, }
# 3.463719 is the largest absolute weight in the embedding
# json_stats: {"epoch": 33, "elapsed": 4.94925737199992, "loss": 3.6854772567749023, }
# 3.765108 is the largest absolute weight in the embedding
# json_stats: {"epoch": 34, "elapsed": 4.925954232999857, "loss": 3.6671712398529053, }
# 4.058077 is the largest absolute weight in the embedding
# json_stats: {"epoch": 35, "elapsed": 4.8969588439999825, "loss": 3.6488945484161377, }
# 4.266837 is the largest absolute weight in the embedding
# json_stats: {"epoch": 36, "elapsed": 4.964029239999945, "loss": 3.6306354999542236, }
# 4.550036 is the largest absolute weight in the embedding
# json_stats: {"epoch": 37, "elapsed": 4.998014925000007, "loss": 3.6128764152526855, }
# 4.824838 is the largest absolute weight in the embedding
# json_stats: {"epoch": 38, "elapsed": 5.383916287999909, "loss": 3.595311403274536, }
# 5.086745 is the largest absolute weight in the embedding
# json_stats: {"epoch": 39, "elapsed": 5.242719296999894, "loss": 3.5768120288848877, }
# 5.369064 is the largest absolute weight in the embedding
# json_stats: {"epoch": 40, "elapsed": 5.378662829999939, "loss": 3.5597333908081055, }
# 5.517095 is the largest absolute weight in the embedding
# json_stats: {"epoch": 41, "elapsed": 5.420079550999844, "loss": 3.5415124893188477, }
# 5.654666 is the largest absolute weight in the embedding
# json_stats: {"epoch": 42, "elapsed": 5.3543520200000785, "loss": 3.5241055488586426, }
# 5.735989 is the largest absolute weight in the embedding
# json_stats: {"epoch": 43, "elapsed": 5.270544016999793, "loss": 3.5074760913848877, }
# 5.810039 is the largest absolute weight in the embedding
# json_stats: {"epoch": 44, "elapsed": 5.293177861000004, "loss": 3.4888081550598145, }
# 6.334749 is the largest absolute weight in the embedding
# json_stats: {"epoch": 45, "elapsed": 5.252123071999904, "loss": 3.471128225326538, }
# 6.917865 is the largest absolute weight in the embedding
# json_stats: {"epoch": 46, "elapsed": 5.275967925000032, "loss": 3.4533281326293945, }
# 7.408433 is the largest absolute weight in the embedding
# json_stats: {"epoch": 47, "elapsed": 5.247847181999987, "loss": 3.4361095428466797, }
# 7.880088 is the largest absolute weight in the embedding
# json_stats: {"epoch": 48, "elapsed": 5.085795072999872, "loss": 3.420449733734131, }
# 8.284557 is the largest absolute weight in the embedding
# json_stats: {"epoch": 49, "elapsed": 5.174825484000166, "loss": 3.402317523956299, }
# 8.736343 is the largest absolute weight in the embedding
# json_stats: {"epoch": 50, "elapsed": 5.293471238999928, "loss": 3.3854122161865234, }
# 9.099413 is the largest absolute weight in the embedding
# json_stats: {"epoch": 51, "elapsed": 5.1957157800000004, "loss": 3.3675453662872314, }
# 9.444212 is the largest absolute weight in the embedding
# json_stats: {"epoch": 52, "elapsed": 5.43329200800008, "loss": 3.352100133895874, }
# 9.768708 is the largest absolute weight in the embedding
# json_stats: {"epoch": 53, "elapsed": 6.214936948000059, "loss": 3.333840847015381, }
# 9.9977 is the largest absolute weight in the embedding
# json_stats: {"epoch": 54, "elapsed": 5.325461693000079, "loss": 3.3165793418884277, }
# 10.325755 is the largest absolute weight in the embedding
# json_stats: {"epoch": 55, "elapsed": 5.337180722000085, "loss": 3.299886465072632, }
# 10.415214 is the largest absolute weight in the embedding
# json_stats: {"epoch": 56, "elapsed": 5.343322247999822, "loss": 3.284618854522705, }
# 10.588818 is the largest absolute weight in the embedding
# json_stats: {"epoch": 57, "elapsed": 5.323191636000047, "loss": 3.2654199600219727, }
# 10.739857 is the largest absolute weight in the embedding
# json_stats: {"epoch": 58, "elapsed": 5.157850434000011, "loss": 3.250016450881958, }
# 10.871916 is the largest absolute weight in the embedding
# json_stats: {"epoch": 59, "elapsed": 5.290949415000114, "loss": 3.2337746620178223, }
# 10.973229 is the largest absolute weight in the embedding
# json_stats: {"epoch": 60, "elapsed": 5.3788920519998555, "loss": 3.2162399291992188, }
# 11.305875 is the largest absolute weight in the embedding
# json_stats: {"epoch": 61, "elapsed": 5.09806977900007, "loss": 3.202204465866089, }
# 11.536093 is the largest absolute weight in the embedding
# json_stats: {"epoch": 62, "elapsed": 5.09680966499991, "loss": 3.184319019317627, }
# 11.667905 is the largest absolute weight in the embedding
# json_stats: {"epoch": 63, "elapsed": 5.117089161999957, "loss": 3.1691999435424805, }
# 11.689686 is the largest absolute weight in the embedding
# json_stats: {"epoch": 64, "elapsed": 5.12823424599992, "loss": 3.155161142349243, }
# 12.274447 is the largest absolute weight in the embedding
# json_stats: {"epoch": 65, "elapsed": 5.130100739999989, "loss": 3.135772228240967, }
# 13.211225 is the largest absolute weight in the embedding
# json_stats: {"epoch": 66, "elapsed": 5.061026990999835, "loss": 3.1238889694213867, }
# 14.071491 is the largest absolute weight in the embedding
# json_stats: {"epoch": 67, "elapsed": 5.08578640099995, "loss": 3.1076138019561768, }
# 14.997982 is the largest absolute weight in the embedding
# json_stats: {"epoch": 68, "elapsed": 5.125055403000033, "loss": 3.0938920974731445, }
# 15.837237 is the largest absolute weight in the embedding
# json_stats: {"epoch": 69, "elapsed": 5.151782149000155, "loss": 3.077589273452759, }
# 16.589803 is the largest absolute weight in the embedding
# json_stats: {"epoch": 70, "elapsed": 5.113754262999919, "loss": 3.062181234359741, }
# 17.266746 is the largest absolute weight in the embedding
# json_stats: {"epoch": 71, "elapsed": 5.195560442999977, "loss": 3.047351121902466, }
# 17.888481 is the largest absolute weight in the embedding
# json_stats: {"epoch": 72, "elapsed": 5.378261762999955, "loss": 3.0379080772399902, }
# 18.504699 is the largest absolute weight in the embedding
# json_stats: {"epoch": 73, "elapsed": 5.3887164430002485, "loss": 3.0228137969970703, }
# 18.986459 is the largest absolute weight in the embedding
# json_stats: {"epoch": 74, "elapsed": 5.41201078999984, "loss": 3.009427070617676, }
# 19.43515 is the largest absolute weight in the embedding
# json_stats: {"epoch": 75, "elapsed": 5.264502080000057, "loss": 2.9940037727355957, }
# 19.846694 is the largest absolute weight in the embedding
# json_stats: {"epoch": 76, "elapsed": 5.293572520999987, "loss": 2.979501485824585, }
# 20.221708 is the largest absolute weight in the embedding
# json_stats: {"epoch": 77, "elapsed": 5.390005043000201, "loss": 2.9699630737304688, }
# 20.503552 is the largest absolute weight in the embedding
# json_stats: {"epoch": 78, "elapsed": 5.508212379999804, "loss": 2.9580283164978027, }
# 20.816602 is the largest absolute weight in the embedding
# json_stats: {"epoch": 79, "elapsed": 5.286876457999824, "loss": 2.9401748180389404, }
# 21.09811 is the largest absolute weight in the embedding
# json_stats: {"epoch": 80, "elapsed": 5.2235233619999235, "loss": 2.92842698097229, }
# 21.316778 is the largest absolute weight in the embedding
# json_stats: {"epoch": 81, "elapsed": 5.347010729999965, "loss": 2.92037034034729, }
# 21.390512 is the largest absolute weight in the embedding
# json_stats: {"epoch": 82, "elapsed": 5.187151201999768, "loss": 2.9055192470550537, }
# 21.561548 is the largest absolute weight in the embedding
# json_stats: {"epoch": 83, "elapsed": 5.282045007999841, "loss": 2.890380859375, }
# 21.923393 is the largest absolute weight in the embedding
# json_stats: {"epoch": 84, "elapsed": 5.183833220999986, "loss": 2.882946491241455, }
# 22.332375 is the largest absolute weight in the embedding
# json_stats: {"epoch": 85, "elapsed": 5.142075370000384, "loss": 2.8688271045684814, }
# 22.658429 is the largest absolute weight in the embedding
# json_stats: {"epoch": 86, "elapsed": 5.35283299699995, "loss": 2.8565351963043213, }
# 22.947139 is the largest absolute weight in the embedding
# json_stats: {"epoch": 87, "elapsed": 5.754442768999979, "loss": 2.8437106609344482, }
# 23.140377 is the largest absolute weight in the embedding
# json_stats: {"epoch": 88, "elapsed": 5.695258511999782, "loss": 2.8351824283599854, }
# 23.295653 is the largest absolute weight in the embedding
# json_stats: {"epoch": 89, "elapsed": 6.117890327999703, "loss": 2.8256947994232178, }
# 23.452065 is the largest absolute weight in the embedding
# json_stats: {"epoch": 90, "elapsed": 5.856606467999882, "loss": 2.8115811347961426, }
# 23.59646 is the largest absolute weight in the embedding
# json_stats: {"epoch": 91, "elapsed": 5.772475665000002, "loss": 2.8028361797332764, }
# 23.652707 is the largest absolute weight in the embedding
# json_stats: {"epoch": 92, "elapsed": 5.800721851000162, "loss": 2.7919607162475586, }
# 23.740328 is the largest absolute weight in the embedding
# json_stats: {"epoch": 93, "elapsed": 6.048968887000228, "loss": 2.780055284500122, }
# 23.817972 is the largest absolute weight in the embedding
# json_stats: {"epoch": 94, "elapsed": 5.854617234000216, "loss": 2.7672359943389893, }
# 23.972812 is the largest absolute weight in the embedding
# json_stats: {"epoch": 95, "elapsed": 5.885470917000021, "loss": 2.7601895332336426, }
# 25.371015 is the largest absolute weight in the embedding
# json_stats: {"epoch": 96, "elapsed": 6.0234968169997956, "loss": 2.7500267028808594, }
# 26.686542 is the largest absolute weight in the embedding
# json_stats: {"epoch": 97, "elapsed": 5.8376309660002335, "loss": 2.7425551414489746, }
# 27.897692 is the largest absolute weight in the embedding
# json_stats: {"epoch": 98, "elapsed": 5.976354685000388, "loss": 2.73370623588562, }
# 29.08398 is the largest absolute weight in the embedding
# json_stats: {"epoch": 99, "elapsed": 5.796312993999891, "loss": 2.7228715419769287, }
# 30.095373 is the largest absolute weight in the embedding
# json_stats: {"epoch": 100, "elapsed": 5.921566670000175, "loss": 2.710270881652832, }
# 31.086728 is the largest absolute weight in the embedding
# json_stats: {"epoch": 101, "elapsed": 5.71597665399986, "loss": 2.704907178878784, }
# 31.896142 is the largest absolute weight in the embedding
# json_stats: {"epoch": 102, "elapsed": 5.777748129999964, "loss": 2.6958370208740234, }
# 32.659351 is the largest absolute weight in the embedding
# json_stats: {"epoch": 103, "elapsed": 5.53537484699973, "loss": 2.6824123859405518, }
# 33.364474 is the largest absolute weight in the embedding
# json_stats: {"epoch": 104, "elapsed": 5.797406789999968, "loss": 2.6750059127807617, }
# 34.002088 is the largest absolute weight in the embedding
# json_stats: {"epoch": 105, "elapsed": 5.77177659400013, "loss": 2.664771318435669, }
# 34.62755 is the largest absolute weight in the embedding
# json_stats: {"epoch": 106, "elapsed": 5.82648108300009, "loss": 2.6527163982391357, }
# 35.221415 is the largest absolute weight in the embedding
# json_stats: {"epoch": 107, "elapsed": 5.628315709000162, "loss": 2.6523306369781494, }
# 35.698694 is the largest absolute weight in the embedding
# json_stats: {"epoch": 108, "elapsed": 5.644489867000175, "loss": 2.6400949954986572, }
# 36.110452 is the largest absolute weight in the embedding
# json_stats: {"epoch": 109, "elapsed": 5.707009576000019, "loss": 2.6297566890716553, }
# 36.467069 is the largest absolute weight in the embedding
# json_stats: {"epoch": 110, "elapsed": 5.752448694999657, "loss": 2.6129138469696045, }
# 36.818451 is the largest absolute weight in the embedding
# json_stats: {"epoch": 111, "elapsed": 5.496675140000207, "loss": 2.60856556892395, }
# 37.153594 is the largest absolute weight in the embedding
# json_stats: {"epoch": 112, "elapsed": 5.6386616620002314, "loss": 2.598329782485962, }
# 37.428538 is the largest absolute weight in the embedding
# json_stats: {"epoch": 113, "elapsed": 5.449664976999884, "loss": 2.5891172885894775, }
# 37.693132 is the largest absolute weight in the embedding
# json_stats: {"epoch": 114, "elapsed": 5.481344669999999, "loss": 2.58181095123291, }
# 37.93818 is the largest absolute weight in the embedding
# json_stats: {"epoch": 115, "elapsed": 5.455028944999867, "loss": 2.5720455646514893, }
# 38.139463 is the largest absolute weight in the embedding
# json_stats: {"epoch": 116, "elapsed": 5.765332852000029, "loss": 2.566291570663452, }
# 38.351284 is the largest absolute weight in the embedding
# json_stats: {"epoch": 117, "elapsed": 5.837798614000349, "loss": 2.5534918308258057, }
# 38.52458 is the largest absolute weight in the embedding
# json_stats: {"epoch": 118, "elapsed": 5.889027290000286, "loss": 2.5477476119995117, }
# 38.673793 is the largest absolute weight in the embedding
# json_stats: {"epoch": 119, "elapsed": 5.833695013000124, "loss": 2.5362205505371094, }
# 38.811929 is the largest absolute weight in the embedding
# json_stats: {"epoch": 120, "elapsed": 5.871429662000082, "loss": 2.528430461883545, }
# 38.933359 is the largest absolute weight in the embedding
# json_stats: {"epoch": 121, "elapsed": 6.122330435000094, "loss": 2.5180912017822266, }
# 39.044511 is the largest absolute weight in the embedding
# json_stats: {"epoch": 122, "elapsed": 5.84252027399998, "loss": 2.511267900466919, }
# 39.146193 is the largest absolute weight in the embedding
# json_stats: {"epoch": 123, "elapsed": 5.427340749999985, "loss": 2.4995477199554443, }
# 39.231716 is the largest absolute weight in the embedding
# json_stats: {"epoch": 124, "elapsed": 8.547056769999926, "loss": 2.4917843341827393, }
# 39.307639 is the largest absolute weight in the embedding
# json_stats: {"epoch": 125, "elapsed": 5.393180951999966, "loss": 2.4826059341430664, }
# 39.380842 is the largest absolute weight in the embedding
# json_stats: {"epoch": 126, "elapsed": 5.146012631999838, "loss": 2.4747471809387207, }
# 39.447104 is the largest absolute weight in the embedding
# json_stats: {"epoch": 127, "elapsed": 5.096611636000034, "loss": 2.4659006595611572, }
# 39.506717 is the largest absolute weight in the embedding
# json_stats: {"epoch": 128, "elapsed": 5.113557811999726, "loss": 2.4582266807556152, }
# 39.563878 is the largest absolute weight in the embedding
# json_stats: {"epoch": 129, "elapsed": 5.132465936000244, "loss": 2.4447696208953857, }
# 39.60807 is the largest absolute weight in the embedding
# json_stats: {"epoch": 130, "elapsed": 5.065011282999876, "loss": 2.4363951683044434, }
# 39.653677 is the largest absolute weight in the embedding
# json_stats: {"epoch": 131, "elapsed": 5.022149164999973, "loss": 2.428668975830078, }
# 39.694287 is the largest absolute weight in the embedding
# json_stats: {"epoch": 132, "elapsed": 4.977009217000159, "loss": 2.42476487159729, }
# 39.732009 is the largest absolute weight in the embedding
# json_stats: {"epoch": 133, "elapsed": 4.977767262999805, "loss": 2.416368007659912, }
# 39.764132 is the largest absolute weight in the embedding
# json_stats: {"epoch": 134, "elapsed": 5.358863979000034, "loss": 2.4114186763763428, }
# 39.792074 is the largest absolute weight in the embedding
# json_stats: {"epoch": 135, "elapsed": 5.314129501000025, "loss": 2.3929460048675537, }
# 39.819649 is the largest absolute weight in the embedding
# json_stats: {"epoch": 136, "elapsed": 5.1871714720000455, "loss": 2.3861539363861084, }
# 39.84413 is the largest absolute weight in the embedding
# json_stats: {"epoch": 137, "elapsed": 5.188293519000126, "loss": 2.375683546066284, }
# 39.867682 is the largest absolute weight in the embedding
# json_stats: {"epoch": 138, "elapsed": 5.277714751000076, "loss": 2.366471529006958, }
# 39.886784 is the largest absolute weight in the embedding
# json_stats: {"epoch": 139, "elapsed": 5.173133975999917, "loss": 2.362018346786499, }
# 39.904951 is the largest absolute weight in the embedding
# json_stats: {"epoch": 140, "elapsed": 5.10613850100026, "loss": 2.3535804748535156, }
# 39.920719 is the largest absolute weight in the embedding
# json_stats: {"epoch": 141, "elapsed": 5.231514592999702, "loss": 2.343839168548584, }
# 39.935732 is the largest absolute weight in the embedding
# json_stats: {"epoch": 142, "elapsed": 5.075095423000221, "loss": 2.3317441940307617, }
# 39.949322 is the largest absolute weight in the embedding
# json_stats: {"epoch": 143, "elapsed": 5.0768128310000975, "loss": 2.328197479248047, }
# 39.96201 is the largest absolute weight in the embedding
# json_stats: {"epoch": 144, "elapsed": 5.095740807999846, "loss": 2.316943407058716, }
# 39.973351 is the largest absolute weight in the embedding
# json_stats: {"epoch": 145, "elapsed": 5.0875587079999605, "loss": 2.3035337924957275, }
# 39.98429 is the largest absolute weight in the embedding
# json_stats: {"epoch": 146, "elapsed": 5.145802772000025, "loss": 2.3055155277252197, }
# 39.993297 is the largest absolute weight in the embedding
# json_stats: {"epoch": 147, "elapsed": 5.100473232999775, "loss": 2.2909669876098633, }
# 40.001823 is the largest absolute weight in the embedding
# json_stats: {"epoch": 148, "elapsed": 5.116539211000145, "loss": 2.2842490673065186, }
# 40.009383 is the largest absolute weight in the embedding
# json_stats: {"epoch": 149, "elapsed": 5.1266936469996836, "loss": 2.2734720706939697, }
# 40.016838 is the largest absolute weight in the embedding
# json_stats: {"epoch": 150, "elapsed": 5.102557636999791, "loss": 2.2729649543762207, }
# 40.022862 is the largest absolute weight in the embedding
# json_stats: {"epoch": 151, "elapsed": 5.088115915999879, "loss": 2.262655735015869, }
# 40.028566 is the largest absolute weight in the embedding
# json_stats: {"epoch": 152, "elapsed": 5.101082643000154, "loss": 2.245177745819092, }
# 40.034309 is the largest absolute weight in the embedding
# json_stats: {"epoch": 153, "elapsed": 5.076904110999749, "loss": 2.2418341636657715, }
# 40.039358 is the largest absolute weight in the embedding
# json_stats: {"epoch": 154, "elapsed": 5.117108874999758, "loss": 2.2319111824035645, }
# 40.044475 is the largest absolute weight in the embedding
# json_stats: {"epoch": 155, "elapsed": 5.106466377999823, "loss": 2.2231218814849854, }
# 40.04853 is the largest absolute weight in the embedding
# json_stats: {"epoch": 156, "elapsed": 5.034414396000102, "loss": 2.215811252593994, }
# 40.052396 is the largest absolute weight in the embedding
# json_stats: {"epoch": 157, "elapsed": 5.072121395000067, "loss": 2.2145628929138184, }
# 40.055812 is the largest absolute weight in the embedding
# json_stats: {"epoch": 158, "elapsed": 5.140353991999746, "loss": 2.200887441635132, }
# 40.059678 is the largest absolute weight in the embedding
# json_stats: {"epoch": 159, "elapsed": 5.085326420000001, "loss": 2.192051887512207, }
# 40.062814 is the largest absolute weight in the embedding
# json_stats: {"epoch": 160, "elapsed": 5.109945422999772, "loss": 2.1768136024475098, }
# 40.065599 is the largest absolute weight in the embedding
# json_stats: {"epoch": 161, "elapsed": 5.093193721000262, "loss": 2.1761116981506348, }
# 40.068215 is the largest absolute weight in the embedding
# json_stats: {"epoch": 162, "elapsed": 5.120615985999848, "loss": 2.1691203117370605, }
# 40.070614 is the largest absolute weight in the embedding
# json_stats: {"epoch": 163, "elapsed": 5.133166530000381, "loss": 2.158897876739502, }
# 40.072748 is the largest absolute weight in the embedding
# json_stats: {"epoch": 164, "elapsed": 5.062939966000158, "loss": 2.1535394191741943, }
# 40.074625 is the largest absolute weight in the embedding
# json_stats: {"epoch": 165, "elapsed": 5.027985064999939, "loss": 2.135038137435913, }
# 40.076476 is the largest absolute weight in the embedding
# json_stats: {"epoch": 166, "elapsed": 5.1063125099999525, "loss": 2.140329599380493, }
# 40.078001 is the largest absolute weight in the embedding
# json_stats: {"epoch": 167, "elapsed": 5.074378804999924, "loss": 2.1308202743530273, }
# 40.079587 is the largest absolute weight in the embedding
# json_stats: {"epoch": 168, "elapsed": 5.094408708999708, "loss": 2.1167383193969727, }
# 40.081136 is the largest absolute weight in the embedding
# json_stats: {"epoch": 169, "elapsed": 5.140459356000065, "loss": 2.110419750213623, }
# 40.082442 is the largest absolute weight in the embedding
# json_stats: {"epoch": 170, "elapsed": 5.3752390989998275, "loss": 2.0991764068603516, }
# 40.083547 is the largest absolute weight in the embedding
# json_stats: {"epoch": 171, "elapsed": 5.309928834999937, "loss": 2.1029067039489746, }
# 40.084643 is the largest absolute weight in the embedding
# json_stats: {"epoch": 172, "elapsed": 5.189822295999875, "loss": 2.0940136909484863, }
# 40.085623 is the largest absolute weight in the embedding
# json_stats: {"epoch": 173, "elapsed": 5.440052707999712, "loss": 2.0799317359924316, }
# 40.086598 is the largest absolute weight in the embedding
# json_stats: {"epoch": 174, "elapsed": 5.4560205660000065, "loss": 2.0791962146759033, }
# 40.087457 is the largest absolute weight in the embedding
# json_stats: {"epoch": 175, "elapsed": 5.177653745000043, "loss": 2.065859317779541, }
# 40.088302 is the largest absolute weight in the embedding
# json_stats: {"epoch": 176, "elapsed": 5.162453883000126, "loss": 2.0609071254730225, }
# 40.089008 is the largest absolute weight in the embedding
# json_stats: {"epoch": 177, "elapsed": 5.197196124000129, "loss": 2.055034637451172, }
# 40.089655 is the largest absolute weight in the embedding
# json_stats: {"epoch": 178, "elapsed": 5.16401968800028, "loss": 2.0374794006347656, }
# 40.090262 is the largest absolute weight in the embedding
# json_stats: {"epoch": 179, "elapsed": 5.1226596520000385, "loss": 2.0356740951538086, }
# 40.090869 is the largest absolute weight in the embedding
# json_stats: {"epoch": 180, "elapsed": 5.192089569000018, "loss": 2.0217833518981934, }
# 40.091409 is the largest absolute weight in the embedding
# json_stats: {"epoch": 181, "elapsed": 5.132339718000367, "loss": 2.021042823791504, }
# 40.091959 is the largest absolute weight in the embedding
# json_stats: {"epoch": 182, "elapsed": 5.114780547999999, "loss": 2.001537561416626, }
# 40.092466 is the largest absolute weight in the embedding
# json_stats: {"epoch": 183, "elapsed": 5.242484401999718, "loss": 1.9889963865280151, }
# 40.092945 is the largest absolute weight in the embedding
# json_stats: {"epoch": 184, "elapsed": 5.192771347999951, "loss": 1.9964797496795654, }
# 40.093368 is the largest absolute weight in the embedding
# json_stats: {"epoch": 185, "elapsed": 5.094156787999964, "loss": 1.9814099073410034, }
# 40.093748 is the largest absolute weight in the embedding
# json_stats: {"epoch": 186, "elapsed": 5.171358031000182, "loss": 1.9667956829071045, }
# 40.094159 is the largest absolute weight in the embedding
# json_stats: {"epoch": 187, "elapsed": 5.09141057800025, "loss": 1.9668943881988525, }
# 40.094542 is the largest absolute weight in the embedding
# json_stats: {"epoch": 188, "elapsed": 5.201201156000025, "loss": 1.9624934196472168, }
# 40.094844 is the largest absolute weight in the embedding
# json_stats: {"epoch": 189, "elapsed": 5.42067121700029, "loss": 1.9480030536651611, }
# 40.095134 is the largest absolute weight in the embedding
# json_stats: {"epoch": 190, "elapsed": 5.344139477000226, "loss": 1.932458758354187, }
# 40.095439 is the largest absolute weight in the embedding
# json_stats: {"epoch": 191, "elapsed": 5.260046585000055, "loss": 1.9356311559677124, }
# 40.095675 is the largest absolute weight in the embedding
# json_stats: {"epoch": 192, "elapsed": 5.346393470999828, "loss": 1.9265705347061157, }
# 40.095896 is the largest absolute weight in the embedding
# json_stats: {"epoch": 193, "elapsed": 5.193248096999923, "loss": 1.9101600646972656, }
# 40.096121 is the largest absolute weight in the embedding
# json_stats: {"epoch": 194, "elapsed": 5.292711226999927, "loss": 1.9053505659103394, }
# 40.096321 is the largest absolute weight in the embedding
# json_stats: {"epoch": 195, "elapsed": 5.20057469800031, "loss": 1.8993895053863525, }
# 40.096527 is the largest absolute weight in the embedding
# json_stats: {"epoch": 196, "elapsed": 5.165597566000088, "loss": 1.9000746011734009, }
# 40.096707 is the largest absolute weight in the embedding
# json_stats: {"epoch": 197, "elapsed": 5.245167007999953, "loss": 1.8823128938674927, }
# 40.096865 is the largest absolute weight in the embedding
# json_stats: {"epoch": 198, "elapsed": 5.259290353999859, "loss": 1.8644483089447021, }
# 40.097022 is the largest absolute weight in the embedding
# json_stats: {"epoch": 199, "elapsed": 5.205816063999919, "loss": 1.864050030708313, }
# 40.09716 is the largest absolute weight in the embedding
# json_stats: {"epoch": 200, "elapsed": 5.390068709999923, "loss": 1.8579195737838745, }
# 40.097303 is the largest absolute weight in the embedding
# json_stats: {"epoch": 201, "elapsed": 5.411000832000354, "loss": 1.8472248315811157, }
# 40.097415 is the largest absolute weight in the embedding
# json_stats: {"epoch": 202, "elapsed": 5.185326645999794, "loss": 1.8300639390945435, }
# 40.097543 is the largest absolute weight in the embedding
# json_stats: {"epoch": 203, "elapsed": 5.216891008999937, "loss": 1.8268697261810303, }
# 40.097642 is the largest absolute weight in the embedding
# json_stats: {"epoch": 204, "elapsed": 5.1151659760002985, "loss": 1.8167451620101929, }
# 40.097736 is the largest absolute weight in the embedding
# json_stats: {"epoch": 205, "elapsed": 5.095924196999931, "loss": 1.8039450645446777, }
# 40.097841 is the largest absolute weight in the embedding
# json_stats: {"epoch": 206, "elapsed": 5.16291511999998, "loss": 1.789542317390442, }
# 40.097924 is the largest absolute weight in the embedding
# json_stats: {"epoch": 207, "elapsed": 5.091298528000152, "loss": 1.782912254333496, }
# 40.097999 is the largest absolute weight in the embedding
# json_stats: {"epoch": 208, "elapsed": 5.138485961000242, "loss": 1.7744985818862915, }
# 40.098069 is the largest absolute weight in the embedding
# json_stats: {"epoch": 209, "elapsed": 5.13135441500026, "loss": 1.7592887878417969, }
# 40.098129 is the largest absolute weight in the embedding
# json_stats: {"epoch": 210, "elapsed": 5.14171417200032, "loss": 1.7532627582550049, }
# 40.098193 is the largest absolute weight in the embedding
# json_stats: {"epoch": 211, "elapsed": 5.1744762499997705, "loss": 1.7423298358917236, }
# 40.098248 is the largest absolute weight in the embedding
# json_stats: {"epoch": 212, "elapsed": 5.136750768000184, "loss": 1.7327479124069214, }
# 40.098298 is the largest absolute weight in the embedding
# json_stats: {"epoch": 213, "elapsed": 5.15351583499978, "loss": 1.722509503364563, }
# 40.098353 is the largest absolute weight in the embedding
# json_stats: {"epoch": 214, "elapsed": 5.188122778999968, "loss": 1.6985143423080444, }
# 40.098398 is the largest absolute weight in the embedding
# json_stats: {"epoch": 215, "elapsed": 5.187144996999905, "loss": 1.6970975399017334, }
# 40.098439 is the largest absolute weight in the embedding
# json_stats: {"epoch": 216, "elapsed": 5.184567326999968, "loss": 1.6880217790603638, }
# 40.098479 is the largest absolute weight in the embedding
# json_stats: {"epoch": 217, "elapsed": 5.105063018000237, "loss": 1.6736862659454346, }
# 40.098514 is the largest absolute weight in the embedding
# json_stats: {"epoch": 218, "elapsed": 5.079221347999919, "loss": 1.6632550954818726, }
# 40.797035 is the largest absolute weight in the embedding
# json_stats: {"epoch": 219, "elapsed": 5.084081265999885, "loss": 1.6579548120498657, }
# 42.673581 is the largest absolute weight in the embedding
# json_stats: {"epoch": 220, "elapsed": 5.1452934150001965, "loss": 1.6372536420822144, }
# 44.19243 is the largest absolute weight in the embedding
# json_stats: {"epoch": 221, "elapsed": 5.15027756299969, "loss": 1.6264253854751587, }
# 45.532315 is the largest absolute weight in the embedding
# json_stats: {"epoch": 222, "elapsed": 5.107112829000016, "loss": 1.6152138710021973, }
# 46.602943 is the largest absolute weight in the embedding
# json_stats: {"epoch": 223, "elapsed": 5.1205545560001156, "loss": 1.6061917543411255, }
# 47.388609 is the largest absolute weight in the embedding
# json_stats: {"epoch": 224, "elapsed": 5.154858390999834, "loss": 1.5910866260528564, }
# 48.146569 is the largest absolute weight in the embedding
# json_stats: {"epoch": 225, "elapsed": 5.076944728999933, "loss": 1.5802022218704224, }
# 48.638519 is the largest absolute weight in the embedding
# json_stats: {"epoch": 226, "elapsed": 5.127616978000333, "loss": 1.5646201372146606, }
# 49.07475 is the largest absolute weight in the embedding
# json_stats: {"epoch": 227, "elapsed": 5.133670939999774, "loss": 1.5597209930419922, }
# 49.40863 is the largest absolute weight in the embedding
# json_stats: {"epoch": 228, "elapsed": 5.158435362000091, "loss": 1.546804428100586, }
# 49.666589 is the largest absolute weight in the embedding
# json_stats: {"epoch": 229, "elapsed": 5.096644136000123, "loss": 1.5363361835479736, }
# 49.90392 is the largest absolute weight in the embedding
# json_stats: {"epoch": 230, "elapsed": 5.1180073299997275, "loss": 1.524925708770752, }
# 50.070604 is the largest absolute weight in the embedding
# json_stats: {"epoch": 231, "elapsed": 5.13864538200005, "loss": 1.525746464729309, }
# 50.188059 is the largest absolute weight in the embedding
# json_stats: {"epoch": 232, "elapsed": 5.099260168000001, "loss": 1.5009833574295044, }
# 50.295422 is the largest absolute weight in the embedding
# json_stats: {"epoch": 233, "elapsed": 5.157835794000221, "loss": 1.4904779195785522, }
# 50.360011 is the largest absolute weight in the embedding
# json_stats: {"epoch": 234, "elapsed": 5.1168793789997835, "loss": 1.475882649421692, }
# 50.426611 is the largest absolute weight in the embedding
# json_stats: {"epoch": 235, "elapsed": 5.17504468199968, "loss": 1.4671194553375244, }
# 50.490948 is the largest absolute weight in the embedding
# json_stats: {"epoch": 236, "elapsed": 5.285700399000234, "loss": 1.4648576974868774, }
# 50.534072 is the largest absolute weight in the embedding
# json_stats: {"epoch": 237, "elapsed": 5.212876835000316, "loss": 1.4569880962371826, }
# 50.56569 is the largest absolute weight in the embedding
# json_stats: {"epoch": 238, "elapsed": 5.124271375999797, "loss": 1.4381027221679688, }
# 50.60535 is the largest absolute weight in the embedding
# json_stats: {"epoch": 239, "elapsed": 5.218790654000259, "loss": 1.4342621564865112, }
# 50.634575 is the largest absolute weight in the embedding
# json_stats: {"epoch": 240, "elapsed": 5.150144594000267, "loss": 1.4110743999481201, }
# 50.657168 is the largest absolute weight in the embedding
# json_stats: {"epoch": 241, "elapsed": 5.161360524999964, "loss": 1.4093482494354248, }
# 50.684683 is the largest absolute weight in the embedding
# json_stats: {"epoch": 242, "elapsed": 5.184072319999814, "loss": 1.4033316373825073, }
# 50.702848 is the largest absolute weight in the embedding
# json_stats: {"epoch": 243, "elapsed": 5.284721171000001, "loss": 1.3976703882217407, }
# 50.707177 is the largest absolute weight in the embedding
# json_stats: {"epoch": 244, "elapsed": 5.174114953999833, "loss": 1.3825852870941162, }
# 50.729678 is the largest absolute weight in the embedding
# json_stats: {"epoch": 245, "elapsed": 5.124312354000267, "loss": 1.376462459564209, }
# 50.747765 is the largest absolute weight in the embedding
# json_stats: {"epoch": 246, "elapsed": 5.111276668999835, "loss": 1.354574203491211, }
# 50.749115 is the largest absolute weight in the embedding
# json_stats: {"epoch": 247, "elapsed": 5.115613116000077, "loss": 1.3453590869903564, }
# 62.386526 is the largest absolute weight in the embedding
# json_stats: {"epoch": 248, "elapsed": 5.120932541000002, "loss": 1.331848382949829, }
# 76.525333 is the largest absolute weight in the embedding
# json_stats: {"epoch": 249, "elapsed": 5.089136892999704, "loss": 1.332407832145691, }
# 91.539604 is the largest absolute weight in the embedding
# json_stats: {"epoch": 250, "elapsed": 5.824933056000191, "loss": 1.322668194770813, }
# 110.469293 is the largest absolute weight in the embedding
# json_stats: {"epoch": 251, "elapsed": 5.93364158400027, "loss": 1.3093363046646118, }
# 131.996125 is the largest absolute weight in the embedding
# json_stats: {"epoch": 252, "elapsed": 5.953430160999687, "loss": 1.3013237714767456, }
# 155.324998 is the largest absolute weight in the embedding
# json_stats: {"epoch": 253, "elapsed": 5.959507125000073, "loss": 1.295568585395813, }
# 183.857329 is the largest absolute weight in the embedding
# json_stats: {"epoch": 254, "elapsed": 5.988206223000361, "loss": 1.2878739833831787, }
# 210.790294 is the largest absolute weight in the embedding
# json_stats: {"epoch": 255, "elapsed": 5.91562246400008, "loss": 1.2669041156768799, }
# 237.641027 is the largest absolute weight in the embedding
# json_stats: {"epoch": 256, "elapsed": 5.854516570000214, "loss": 1.2555115222930908, }
# 264.504464 is the largest absolute weight in the embedding
# json_stats: {"epoch": 257, "elapsed": 5.879215311999815, "loss": 1.2569531202316284, }
# 291.012801 is the largest absolute weight in the embedding
# json_stats: {"epoch": 258, "elapsed": 5.838388843999837, "loss": 1.2375333309173584, }
# 317.03316 is the largest absolute weight in the embedding
# json_stats: {"epoch": 259, "elapsed": 5.91772773699995, "loss": 1.2465252876281738, }
# 337.412436 is the largest absolute weight in the embedding
# json_stats: {"epoch": 260, "elapsed": 5.964434703999814, "loss": 1.2352832555770874, }
# 351.290225 is the largest absolute weight in the embedding
# json_stats: {"epoch": 261, "elapsed": 5.972033163000106, "loss": 1.2191082239151, }
# 361.907752 is the largest absolute weight in the embedding
# json_stats: {"epoch": 262, "elapsed": 5.89862436400017, "loss": 1.213610291481018, }
# 366.148599 is the largest absolute weight in the embedding
# json_stats: {"epoch": 263, "elapsed": 5.964903485999912, "loss": 1.2045314311981201, }
# 395.079536 is the largest absolute weight in the embedding
# json_stats: {"epoch": 264, "elapsed": 5.9609618629997385, "loss": 1.1975075006484985, }
# 438.447819 is the largest absolute weight in the embedding
# json_stats: {"epoch": 265, "elapsed": 5.964187711999784, "loss": 1.1885807514190674, }
# 478.834455 is the largest absolute weight in the embedding
# json_stats: {"epoch": 266, "elapsed": 5.925844192000113, "loss": 1.1960641145706177, }
# 514.707675 is the largest absolute weight in the embedding
# json_stats: {"epoch": 267, "elapsed": 5.91421930100023, "loss": 1.1749922037124634, }
# 544.341946 is the largest absolute weight in the embedding
# json_stats: {"epoch": 268, "elapsed": 5.8472183629996834, "loss": 1.165865182876587, }
# 574.848287 is the largest absolute weight in the embedding
# json_stats: {"epoch": 269, "elapsed": 5.852057519000027, "loss": 1.1642063856124878, }
# 599.788184 is the largest absolute weight in the embedding
# json_stats: {"epoch": 270, "elapsed": 5.244746739999755, "loss": 1.1485234498977661, }
# 622.610607 is the largest absolute weight in the embedding
# json_stats: {"epoch": 271, "elapsed": 5.133755357999689, "loss": 1.1539909839630127, }
# 640.22755 is the largest absolute weight in the embedding
# json_stats: {"epoch": 272, "elapsed": 5.125431575000221, "loss": 1.1353826522827148, }
# 654.294686 is the largest absolute weight in the embedding
# json_stats: {"epoch": 273, "elapsed": 5.172454398000355, "loss": 1.1269997358322144, }
# 667.493357 is the largest absolute weight in the embedding
# json_stats: {"epoch": 274, "elapsed": 5.126597358000254, "loss": 1.1223915815353394, }
# 677.101333 is the largest absolute weight in the embedding
# json_stats: {"epoch": 275, "elapsed": 5.156562387000122, "loss": 1.1197543144226074, }
# 685.795684 is the largest absolute weight in the embedding
# json_stats: {"epoch": 276, "elapsed": 5.1930516580000585, "loss": 1.107012391090393, }
# 692.68101 is the largest absolute weight in the embedding
# json_stats: {"epoch": 277, "elapsed": 5.152222789000007, "loss": 1.1000909805297852, }
# 698.630014 is the largest absolute weight in the embedding
# json_stats: {"epoch": 278, "elapsed": 5.194053475000146, "loss": 1.0958396196365356, }
# 703.428379 is the largest absolute weight in the embedding
# json_stats: {"epoch": 279, "elapsed": 5.143013394999798, "loss": 1.091291904449463, }
# 707.453801 is the largest absolute weight in the embedding
# json_stats: {"epoch": 280, "elapsed": 5.214806781999869, "loss": 1.0824395418167114, }
# 710.541396 is the largest absolute weight in the embedding
# json_stats: {"epoch": 281, "elapsed": 5.1456685969997125, "loss": 1.0686662197113037, }
# 713.482255 is the largest absolute weight in the embedding
# json_stats: {"epoch": 282, "elapsed": 5.177550813999915, "loss": 1.0728390216827393, }
# 715.710604 is the largest absolute weight in the embedding
# json_stats: {"epoch": 283, "elapsed": 5.113420293999752, "loss": 1.0600383281707764, }
# 717.819756 is the largest absolute weight in the embedding
# json_stats: {"epoch": 284, "elapsed": 5.153199605000282, "loss": 1.0574123859405518, }
# 719.345451 is the largest absolute weight in the embedding
# json_stats: {"epoch": 285, "elapsed": 5.073207711000123, "loss": 1.0544195175170898, }
# 720.838954 is the largest absolute weight in the embedding
# json_stats: {"epoch": 286, "elapsed": 5.398424610999882, "loss": 1.035152792930603, }
# 721.900641 is the largest absolute weight in the embedding
# json_stats: {"epoch": 287, "elapsed": 5.881500502000108, "loss": 1.0286732912063599, }
# 722.845998 is the largest absolute weight in the embedding
# json_stats: {"epoch": 288, "elapsed": 5.806126983000013, "loss": 1.038443922996521, }
# 723.580693 is the largest absolute weight in the embedding
# json_stats: {"epoch": 289, "elapsed": 5.8335688729998765, "loss": 1.0205726623535156, }
# 724.303645 is the largest absolute weight in the embedding
# json_stats: {"epoch": 290, "elapsed": 5.826680628000304, "loss": 1.0130560398101807, }
# 724.882574 is the largest absolute weight in the embedding
# json_stats: {"epoch": 291, "elapsed": 5.890406415000143, "loss": 1.0134750604629517, }
# 725.312694 is the largest absolute weight in the embedding
# json_stats: {"epoch": 292, "elapsed": 5.861646826000197, "loss": 1.0042507648468018, }
# 725.705563 is the largest absolute weight in the embedding
# json_stats: {"epoch": 293, "elapsed": 5.874856917000216, "loss": 1.0067716836929321, }
# 726.039828 is the largest absolute weight in the embedding
# json_stats: {"epoch": 294, "elapsed": 5.877360406000207, "loss": 0.9898599982261658, }
# 726.313108 is the largest absolute weight in the embedding
# json_stats: {"epoch": 295, "elapsed": 5.843034227999851, "loss": 0.9951092004776001, }
# 726.556931 is the largest absolute weight in the embedding
# json_stats: {"epoch": 296, "elapsed": 5.8475767499999165, "loss": 0.9892868399620056, }
# 726.77094 is the largest absolute weight in the embedding
# json_stats: {"epoch": 297, "elapsed": 5.897133477999887, "loss": 0.968397855758667, }
# 726.960986 is the largest absolute weight in the embedding
# json_stats: {"epoch": 298, "elapsed": 5.852781255000082, "loss": 0.9751577377319336, }
# 727.130675 is the largest absolute weight in the embedding
# json_stats: {"epoch": 299, "elapsed": 5.837471552999887, "loss": 0.9614731669425964, }
# 727.291382 is the largest absolute weight in the embedding
# json_stats: {"epoch": 300, "elapsed": 5.89617637099991, "loss": 0.9461194276809692, }
# 727.417471 is the largest absolute weight in the embedding
# json_stats: {"epoch": 301, "elapsed": 5.9377429389996905, "loss": 0.9554747939109802, }
# 727.527049 is the largest absolute weight in the embedding
# json_stats: {"epoch": 302, "elapsed": 5.354105661999711, "loss": 0.9493509531021118, }
# 727.62546 is the largest absolute weight in the embedding
# json_stats: {"epoch": 303, "elapsed": 5.223196272000223, "loss": 0.9513562321662903, }
# 727.71343 is the largest absolute weight in the embedding
# json_stats: {"epoch": 304, "elapsed": 5.156747596999594, "loss": 0.9408645033836365, }
# 727.790523 is the largest absolute weight in the embedding
# json_stats: {"epoch": 305, "elapsed": 5.156331986999703, "loss": 0.9319700598716736, }
# 727.851025 is the largest absolute weight in the embedding
# json_stats: {"epoch": 306, "elapsed": 5.064478953000162, "loss": 0.928736686706543, }
# 727.906016 is the largest absolute weight in the embedding
# json_stats: {"epoch": 307, "elapsed": 5.1634567199998855, "loss": 0.9297058582305908, }
# 727.961648 is the largest absolute weight in the embedding
# json_stats: {"epoch": 308, "elapsed": 5.111057016999894, "loss": 0.9049757122993469, }
# 728.000359 is the largest absolute weight in the embedding
# json_stats: {"epoch": 309, "elapsed": 5.146777917000236, "loss": 0.9093865156173706, }
# 728.042229 is the largest absolute weight in the embedding
# json_stats: {"epoch": 310, "elapsed": 5.099815225000384, "loss": 0.9133270382881165, }
# 728.078223 is the largest absolute weight in the embedding
# json_stats: {"epoch": 311, "elapsed": 5.089589889999843, "loss": 0.9114407300949097, }
# 728.106885 is the largest absolute weight in the embedding
# json_stats: {"epoch": 312, "elapsed": 5.133451862999664, "loss": 0.8966476917266846, }
# 728.136383 is the largest absolute weight in the embedding
# json_stats: {"epoch": 313, "elapsed": 5.09134113600021, "loss": 0.8906087279319763, }
# 728.16159 is the largest absolute weight in the embedding
# json_stats: {"epoch": 314, "elapsed": 5.0773743129998365, "loss": 0.8818608522415161, }
# 728.182823 is the largest absolute weight in the embedding
# json_stats: {"epoch": 315, "elapsed": 5.102173150999988, "loss": 0.8820491433143616, }
# 728.201386 is the largest absolute weight in the embedding
# json_stats: {"epoch": 316, "elapsed": 5.07300941099993, "loss": 0.8784967064857483, }
# 728.217989 is the largest absolute weight in the embedding
# json_stats: {"epoch": 317, "elapsed": 5.120808433000093, "loss": 0.8679828643798828, }
# 728.232258 is the largest absolute weight in the embedding
# json_stats: {"epoch": 318, "elapsed": 5.052723630999935, "loss": 0.8712388277053833, }
# 728.246017 is the largest absolute weight in the embedding
# json_stats: {"epoch": 319, "elapsed": 5.134903580000355, "loss": 0.858281135559082, }
# 728.257979 is the largest absolute weight in the embedding
# json_stats: {"epoch": 320, "elapsed": 5.104980221999995, "loss": 0.8545505404472351, }
# 728.267535 is the largest absolute weight in the embedding
# json_stats: {"epoch": 321, "elapsed": 5.149524743999791, "loss": 0.8545035123825073, }
# 728.276025 is the largest absolute weight in the embedding
# json_stats: {"epoch": 322, "elapsed": 5.1086120949998985, "loss": 0.8529790639877319, }
# 728.284217 is the largest absolute weight in the embedding
# json_stats: {"epoch": 323, "elapsed": 5.077821889000006, "loss": 0.8427797555923462, }
# 728.291525 is the largest absolute weight in the embedding
# json_stats: {"epoch": 324, "elapsed": 5.083930455999962, "loss": 0.8387109041213989, }
# 728.297586 is the largest absolute weight in the embedding
# json_stats: {"epoch": 325, "elapsed": 5.181428805999985, "loss": 0.8288140892982483, }
# ...
# json_stats: {"epoch": 891, "elapsed": 5.677153214999635, "loss": 0.23078195750713348, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 892, "elapsed": 5.7363830530002815, "loss": 0.22759602963924408, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 893, "elapsed": 5.881089620999774, "loss": 0.22871017456054688, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 894, "elapsed": 5.814211771000373, "loss": 0.23001088201999664, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 895, "elapsed": 5.782068149999759, "loss": 0.22930137813091278, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 896, "elapsed": 5.610368093999568, "loss": 0.22724062204360962, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 897, "elapsed": 5.715562063000107, "loss": 0.23232047259807587, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 898, "elapsed": 5.844443077999131, "loss": 0.2312457263469696, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 899, "elapsed": 6.060927479999918, "loss": 0.22940003871917725, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 900, "elapsed": 5.960959011999876, "loss": 0.2283865213394165, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 901, "elapsed": 5.912973268999849, "loss": 0.2283184677362442, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 902, "elapsed": 5.889206136000212, "loss": 0.22775349020957947, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 903, "elapsed": 5.936104795999199, "loss": 0.2228282243013382, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 904, "elapsed": 6.040273085999615, "loss": 0.22764401137828827, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 905, "elapsed": 6.381316379000054, "loss": 0.22632645070552826, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 906, "elapsed": 6.2441935560000275, "loss": 0.22940151393413544, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 907, "elapsed": 6.10027110899955, "loss": 0.22595468163490295, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 908, "elapsed": 6.017260663999878, "loss": 0.22385789453983307, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 909, "elapsed": 6.142122856999777, "loss": 0.22430570423603058, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 910, "elapsed": 6.00892245400064, "loss": 0.22742052376270294, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 911, "elapsed": 6.143947950000438, "loss": 0.22514817118644714, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 912, "elapsed": 11.3201720069992, "loss": 0.2312108427286148, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 913, "elapsed": 6.812000851000448, "loss": 0.2257782220840454, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 914, "elapsed": 6.7849003999999695, "loss": 0.22365796566009521, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 915, "elapsed": 6.941362546000164, "loss": 0.22880622744560242, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 916, "elapsed": 6.9043804060002, "loss": 0.2230178415775299, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 917, "elapsed": 6.855605452999953, "loss": 0.2251407653093338, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 918, "elapsed": 6.317838983999536, "loss": 0.2268013209104538, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 919, "elapsed": 5.973873050000293, "loss": 0.2261895388364792, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 920, "elapsed": 5.829827243999716, "loss": 0.22534824907779694, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 921, "elapsed": 5.979938366999704, "loss": 0.223501518368721, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 922, "elapsed": 5.892648667000685, "loss": 0.22143369913101196, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 923, "elapsed": 5.812524136999855, "loss": 0.22702406346797943, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 924, "elapsed": 6.039775602999725, "loss": 0.22370827198028564, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 925, "elapsed": 5.821800360999987, "loss": 0.22291436791419983, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 926, "elapsed": 5.987551952999638, "loss": 0.22345741093158722, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 927, "elapsed": 5.817436222999277, "loss": 0.21746228635311127, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 928, "elapsed": 5.836825358000169, "loss": 0.218868687748909, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 929, "elapsed": 5.705231488999743, "loss": 0.224546417593956, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 930, "elapsed": 5.677311088999886, "loss": 0.21986404061317444, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 931, "elapsed": 5.8539539230005175, "loss": 0.22177116572856903, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 932, "elapsed": 6.046133993000694, "loss": 0.22443002462387085, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 933, "elapsed": 5.843616731000111, "loss": 0.219369575381279, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 934, "elapsed": 5.763814605000334, "loss": 0.22187647223472595, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 935, "elapsed": 5.928667991000111, "loss": 0.2204621434211731, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 936, "elapsed": 5.830304351999985, "loss": 0.22128178179264069, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 937, "elapsed": 5.856448808000096, "loss": 0.21838191151618958, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 938, "elapsed": 5.762367319000077, "loss": 0.21982842683792114, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 939, "elapsed": 6.059782607999296, "loss": 0.2181115746498108, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 940, "elapsed": 5.68973934800033, "loss": 0.2182263433933258, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 941, "elapsed": 5.787829255999895, "loss": 0.22043271362781525, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 942, "elapsed": 5.702398245999575, "loss": 0.2138536423444748, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 943, "elapsed": 5.680722838999827, "loss": 0.22216017544269562, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 944, "elapsed": 5.766590207000263, "loss": 0.22298108041286469, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 945, "elapsed": 5.697648287999982, "loss": 0.22239792346954346, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 946, "elapsed": 5.855562015000032, "loss": 0.2212817370891571, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 947, "elapsed": 5.8223371909998605, "loss": 0.2184537947177887, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 948, "elapsed": 6.041925695999453, "loss": 0.22216138243675232, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 949, "elapsed": 5.920204349999949, "loss": 0.22146829962730408, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 950, "elapsed": 5.864589339000304, "loss": 0.2165944129228592, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 951, "elapsed": 6.071393318999981, "loss": 0.22199949622154236, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 952, "elapsed": 5.9228137540003445, "loss": 0.21876485645771027, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 953, "elapsed": 5.890398104999804, "loss": 0.21757498383522034, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 954, "elapsed": 5.587565738000194, "loss": 0.21791377663612366, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 955, "elapsed": 5.799237606999668, "loss": 0.21761426329612732, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 956, "elapsed": 5.8955126279997785, "loss": 0.21743713319301605, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 957, "elapsed": 5.830067382999914, "loss": 0.21769025921821594, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 958, "elapsed": 5.855913961000624, "loss": 0.21351204812526703, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 959, "elapsed": 6.090019044999281, "loss": 0.21609032154083252, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 960, "elapsed": 5.763103856999805, "loss": 0.21703042089939117, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 961, "elapsed": 5.781198081000184, "loss": 0.21695080399513245, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 962, "elapsed": 5.756049406000784, "loss": 0.21531066298484802, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 963, "elapsed": 5.768861468000068, "loss": 0.21401911973953247, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 964, "elapsed": 5.8146657119996235, "loss": 0.21785061061382294, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 965, "elapsed": 5.842883401000108, "loss": 0.21552187204360962, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 966, "elapsed": 6.0040225259999715, "loss": 0.21508727967739105, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 967, "elapsed": 6.045236021999699, "loss": 0.21332420408725739, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 968, "elapsed": 5.69591365999986, "loss": 0.21308055520057678, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 969, "elapsed": 5.6754718610000054, "loss": 0.2160460501909256, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 970, "elapsed": 5.722600116000649, "loss": 0.2128089964389801, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 971, "elapsed": 5.767713070999889, "loss": 0.2153901755809784, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 972, "elapsed": 5.7722480149996045, "loss": 0.21305084228515625, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 973, "elapsed": 5.757023334000223, "loss": 0.21283692121505737, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 974, "elapsed": 5.788878442000168, "loss": 0.21646912395954132, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 975, "elapsed": 5.806738721999864, "loss": 0.2176184356212616, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 976, "elapsed": 5.817400136000288, "loss": 0.21416008472442627, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 977, "elapsed": 6.0277454080005555, "loss": 0.21369749307632446, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 978, "elapsed": 5.822929498999656, "loss": 0.21317051351070404, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 979, "elapsed": 5.817419754000184, "loss": 0.21531255543231964, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 980, "elapsed": 5.906880072999229, "loss": 0.21403436362743378, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 981, "elapsed": 5.731189185000403, "loss": 0.21232689917087555, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 982, "elapsed": 5.696412651999708, "loss": 0.21401658654212952, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 983, "elapsed": 5.867619599000136, "loss": 0.21075522899627686, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 984, "elapsed": 5.833597801999531, "loss": 0.21109768748283386, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 985, "elapsed": 5.7907987290000165, "loss": 0.21007902920246124, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 986, "elapsed": 5.737142111000139, "loss": 0.2133101373910904, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 987, "elapsed": 5.813566193000042, "loss": 0.21492944657802582, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 988, "elapsed": 5.746359347999714, "loss": 0.21225835382938385, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 989, "elapsed": 5.85036866199971, "loss": 0.21119564771652222, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 990, "elapsed": 5.7980718729995715, "loss": 0.2106923758983612, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 991, "elapsed": 5.740195414000482, "loss": 0.21320782601833344, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 992, "elapsed": 5.7598519960001795, "loss": 0.21247532963752747, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 993, "elapsed": 5.784651943999961, "loss": 0.2106996476650238, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 994, "elapsed": 5.808177388999866, "loss": 0.21137918531894684, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 995, "elapsed": 5.762521689000096, "loss": 0.21303576231002808, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 996, "elapsed": 5.913440844000434, "loss": 0.21228697896003723, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 997, "elapsed": 5.765517732999797, "loss": 0.20923630893230438, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 998, "elapsed": 5.808745253999405, "loss": 0.20921432971954346, }
# 728.358186 is the largest absolute weight in the embedding
# json_stats: {"epoch": 999, "elapsed": 5.633014764999643, "loss": 0.2106168121099472, }
# Total training time is: 5605.929422123

# %% [markdown]
# # Evaluate embedding

# %%
model_weight = model.lt.weight.clone()
meanrank, maprank = eval_reconstruction(adj, model_weight, 
                                        manifold.distance, workers=opt_ndproc)
sqnorms = manifold.pnorm(model_weight)
sqnorm_min = sqnorms.min().item()
sqnorm_avg = sqnorms.mean().item()
sqnorm_avg = sqnorms.mean().item()
sqnorm_max = sqnorms.max().item()
eval_res = [meanrank, maprank, sqnorm_min, sqnorm_avg, sqnorm_max, train_time]
RESULTS = RES(loss, eval_res, model_weight)
torch.save(RESULTS, "./results_weights/"+FILE_NAME+"_seed1"+".pt")
log.info(
    'json_stats final test: \n{'
    f'"sqnorm_min": {round(sqnorm_min,6)}, '
    f'"sqnorm_avg": {round(sqnorm_avg,6)}, '
    f'"sqnorm_max": {round(sqnorm_max,6)}, \n'
    f'"mean_rank": {round(meanrank,6)}, '
    f'"map": {round(maprank,6)}, '
    '}'
)
print(model.lt.weight.data[0])
# Out:
# json_stats final test:
# {"sqnorm_min": 0.400126, "sqnorm_avg": 0.998937, "sqnorm_max": 1.0,
# "mean_rank": 1.526453, "map": 0.914848, }
# tensor([[1.9372e+00, 1.0822e-13],
#         [2.4627e-11, 6.8927e-28]], dtype=torch.float64)
